# %%
import pandas as pd
import numpy as np

df=pd.read_csv('master_instruments2.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ExchangeSegment', 'ExchangeInstrumentID', 'Name',
#        'Description', 'Series', 'NameWithSeries', 'InstrumentID',
#        'PriceBand.High', 'PriceBand.Low', 'FreezeQty', 'TickSize', 'LotSize',
#        'Multiplier', 'displayName', 'ExpiryDate', 'Strike', 'OptionType',
#        'TickerName'],
#       dtype='object')

# %%
import json
import csv

# Desired CSV columns:
# Index(['Unnamed: 0', 'ExchangeSegment', 'ExchangeInstrumentID', 'Name',
#        'Description', 'Series', 'NameWithSeries', 'InstrumentID',
#        'PriceBand.High', 'PriceBand.Low', 'FreezeQty', 'TickSize', 'LotSize',
#        'Multiplier', 'displayName', 'ExpiryDate', 'Strike', 'OptionType',
#        'TickerName'],
#       dtype='object')
#
# In our mapping from the pipe‑delimited string (with 23 fields), we use:
#
# Record fields (indices):
#  0: ExchangeSegment                -> CSV: ExchangeSegment
#  1: ExchangeInstrumentID           -> CSV: ExchangeInstrumentID
#  2: (ignored)
#  3: Name                           -> CSV: Name and displayName
#  4: Contract Symbol (e.g. CONCOR25APR780PE) -> used to extract Series & NameWithSeries
#  5: (ignored)
#  6: (ignored)
#  7: InstrumentID                   -> CSV: InstrumentID
#  8: PriceBand.High                 -> CSV: PriceBand.High
#  9: PriceBand.Low                  -> CSV: PriceBand.Low
# 10: FreezeQty                      -> CSV: FreezeQty
# 11: TickSize                       -> CSV: TickSize
# 12: LotSize                        -> CSV: LotSize
# 13: Multiplier                     -> CSV: Multiplier
# 14: (ignored)
# 15: (often same as Name)           -> (ignored, we use Name from index 3)
# 16: ExpiryDate                     -> CSV: ExpiryDate
# 17: Strike                         -> CSV: Strike
# 18: OptionType                     -> CSV: OptionType
# 19: Description (option description) -> CSV: Description
# 20: (ignored)
# 21: (ignored)
# 22: TickerName (usually same as the contract symbol) -> CSV: TickerName
#
# We also generate "Unnamed: 0" as a sequential index.

# Define header for CSV
csv_header = [
    "Unnamed: 0",
    "ExchangeSegment",
    "ExchangeInstrumentID",
    "Name",
    "Description",
 
    "NameWithSeries",
    "InstrumentID",
    "PriceBand.High",
    "PriceBand.Low",
    "FreezeQty",
    "TickSize",
    "LotSize",
    "Multiplier",
    "displayName",
    "ExpiryDate",
    "Strike",
    "OptionType",
    "TickerName"
]

def parse_record(record_str):
    """
    Splits a pipe-delimited string and returns the list of fields.
    """
    fields = record_str.split("|")
    if len(fields) < 23:
        print(f"Warning: Expected at least 23 fields, but got {len(fields)} in record: {record_str}")
    return fields

def extract_series(contract_symbol):
    """
    Extracts the option series (e.g. 'CE' or 'PE') from the contract symbol.
    Assumes the series is the last two characters.
    """
    return contract_symbol[-2:] if len(contract_symbol) >= 2 else ""

def main():
    # Read the JSON file containing the pipe-delimited strings.
    with open("master_instruments.json", "r") as f:
        data = json.load(f)
    
    csv_rows = []
    
    for idx, record_str in enumerate(data):
        fields = parse_record(record_str)
        # Ensure we have enough fields to map our data (we need index up to 22)
        if len(fields) < 23:
            continue  # skip or handle as needed

        # Map the fields to the desired CSV columns
        # Using the mapping defined in the header comments above.
        row = [
            idx,                        # Unnamed: 0 (sequential index)
            fields[0],                  # ExchangeSegment
            fields[1],                  # ExchangeInstrumentID
            fields[3],                  # Name
            fields[19],                 # Description (option description)
        
            fields[4],                  # NameWithSeries (the full contract symbol)
            fields[7],                  # InstrumentID
            fields[8],                  # PriceBand.High
            fields[9],                  # PriceBand.Low
            fields[10],                 # FreezeQty
            fields[11],                 # TickSize
            fields[12],                 # LotSize
            fields[13],                 # Multiplier
            fields[3],                  # displayName (using Name from index 3)
            fields[16],                 # ExpiryDate
            fields[17],                 # Strike
            fields[18],                 # OptionType
            fields[22]                  # TickerName (contract code)
        ]
        csv_rows.append(row)
    
    # Write the rows to CSV
    with open("data.csv", "w", newline="") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(csv_header)
        writer.writerows(csv_rows)
    
    print("CSV file 'data.csv' created successfully.")

if __name__ == "__main__":
    main()
# Out:
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|69079|1|ASIANPAINT|ASIANPAINT25APRFUT|FUTSTK|ASIANPAINT-FUTSTK|2511400069079|2485.15|2033.3|10001|0.05|200|1|1100100000236|ASIANPAINT|2025-04-24T14:30:00|ASIANPAINT 24APR2025|1|1|ASIANPAINT25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73466|1|JIOFIN|JIOFIN25APRFUT|FUTSTK|JIOFIN-FUTSTK|2511400073466|254.49|208.22|82501|0.01|1650|1|1100100018143|JIOFIN|2025-04-24T14:30:00|JIOFIN 24APR2025|1|1|JIOFIN25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43355|1|SBIN|SBIN25MARFUT|FUTSTK|SBIN-FUTSTK|2508600043355|812.2|664.55|30001|0.05|750|1|1100100003045|SBIN|2025-03-27T14:30:00|SBIN 27MAR2025|1|1|SBIN25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43438|1|WIPRO|WIPRO25MARFUT|FUTSTK|WIPRO-FUTSTK|2508600043438|343.7|281.25|90001|0.05|3000|1|1100100003787|WIPRO|2025-03-27T14:30:00|WIPRO 27MAR2025|1|1|WIPRO25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73487|1|M&M|M&M25APRFUT|FUTSTK|M&M-FUTSTK|2511400073487|3332.25|2726.4|7001|0.05|175|1|1100100002031|M&M|2025-04-24T14:30:00|M&M 24APR2025|1|1|M&M25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38495|1|DRREDDY|DRREDDY25FEBFUT|FUTSTK|DRREDDY-FUTSTK|2505800038495|1330.95|1089|18751|0.05|625|1|1100100000881|DRREDDY|2025-02-27T14:30:00|DRREDDY 27FEB2025|1|1|DRREDDY25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73281|1|CROMPTON|CROMPTON25APRFUT|FUTSTK|CROMPTON-FUTSTK|2511400073281|378.8|309.95|54001|0.05|1800|1|1100100017094|CROMPTON|2025-04-24T14:30:00|CROMPTON 24APR2025|1|1|CROMPTON25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73678|1|VBL|VBL25APRFUT|FUTSTK|VBL-FUTSTK|2511400073678|594.8|486.65|35001|0.05|875|1|1100100018921|VBL|2025-04-24T14:30:00|VBL 24APR2025|1|1|VBL25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35311|1|BAJAJ-AUTO|BAJAJ-AUTO25FEBFUT|FUTSTK|BAJAJ-AUTO-FUTSTK|2505800035311|9603.65|7857.5|3001|0.05|75|1|1100100016669|BAJAJ-AUTO|2025-02-27T14:30:00|BAJAJ-AUTO 27FEB2025|1|1|BAJAJ-AUTO25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35524|1|CIPLA|CIPLA25MARFUT|FUTSTK|CIPLA-FUTSTK|2508600035524|1604.9|1313.1|16251|0.05|325|1|1100100000694|CIPLA|2025-03-27T14:30:00|CIPLA 27MAR2025|1|1|CIPLA25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73679|1|VEDL|VEDL25APRFUT|FUTSTK|VEDL-FUTSTK|2511400073679|470.55|385|46001|0.05|1150|1|1100100003063|VEDL|2025-04-24T14:30:00|VEDL 24APR2025|1|1|VEDL25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43269|1|PEL|PEL25MARFUT|FUTSTK|PEL-FUTSTK|2508600043269|1085.1|887.85|22501|0.05|750|1|1100100002412|PEL|2025-03-27T14:30:00|PEL 27MAR2025|1|1|PEL25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|40481|1|IRB|IRB25MARFUT|FUTSTK|IRB-FUTSTK|2508600040481|55.11|45.09|410001|0.01|10250|1|1100100015313|IRB|2025-03-27T14:30:00|IRB 27MAR2025|1|1|IRB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73572|1|SONACOMS|SONACOMS25APRFUT|FUTSTK|SONACOMS-FUTSTK|2511400073572|569.65|466.1|38751|0.05|775|1|1100100004684|SONACOMS|2025-04-24T14:30:00|SONACOMS 24APR2025|1|1|SONACOMS25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73344|1|HEROMOTOCO|HEROMOTOCO25APRFUT|FUTSTK|HEROMOTOCO-FUTSTK|2511400073344|4482.7|3667.65|6001|0.05|150|1|1100100001348|HEROMOTOCO|2025-04-24T14:30:00|HEROMOTOCO 24APR2025|1|1|HEROMOTOCO25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73288|1|DIVISLAB|DIVISLAB25APRFUT|FUTSTK|DIVISLAB-FUTSTK|2511400073288|6658.25|5447.7|4001|0.05|100|1|1100100010940|DIVISLAB|2025-04-24T14:30:00|DIVISLAB 24APR2025|1|1|DIVISLAB25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35223|1|ATGL|ATGL25MARFUT|FUTSTK|ATGL-FUTSTK|2508600035223|626.9|512.95|31001|0.05|775|1|1100100006066|ATGL|2025-03-27T14:30:00|ATGL 27MAR2025|1|1|ATGL25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|40399|1|INDUSINDBK|INDUSINDBK25MARFUT|FUTSTK|INDUSINDBK-FUTSTK|2508600040399|1150.5|941.35|25001|0.05|500|1|1100100005258|INDUSINDBK|2025-03-27T14:30:00|INDUSINDBK 27MAR2025|1|1|INDUSINDBK25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|41385|1|TATACHEM|TATACHEM25FEBFUT|FUTSTK|TATACHEM-FUTSTK|2505800041385|970.55|794.1|22001|0.05|550|1|1100100003405|TATACHEM|2025-02-27T14:30:00|TATACHEM 27FEB2025|1|1|TATACHEM25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73669|1|TRENT|TRENT25APRFUT|FUTSTK|TRENT-FUTSTK|2511400073669|5849.4|4785.85|4001|0.05|100|1|1100100001964|TRENT|2025-04-24T14:30:00|TRENT 24APR2025|1|1|TRENT25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38263|1|CYIENT|CYIENT25FEBFUT|FUTSTK|CYIENT-FUTSTK|2505800038263|1583.55|1295.6|15001|0.05|300|1|1100100005748|CYIENT|2025-02-27T14:30:00|CYIENT 27FEB2025|1|1|CYIENT25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|40382|1|OFSS|OFSS25FEBFUT|FUTSTK|OFSS-FUTSTK|2505800040382|9982.45|8167.5|2001|0.05|50|1|1100100010738|OFSS|2025-02-27T14:30:00|OFSS 27FEB2025|1|1|OFSS25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39213|1|MGL|MGL25FEBFUT|FUTSTK|MGL-FUTSTK|2505800039213|1434.95|1174.05|20001|0.05|400|1|1100100017534|MGL|2025-02-27T14:30:00|MGL 27FEB2025|1|1|MGL25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73479|1|LAURUSLABS|LAURUSLABS25APRFUT|FUTSTK|LAURUSLABS-FUTSTK|2511400073479|669.65|547.9|51001|0.05|1700|1|1100100019234|LAURUSLABS|2025-04-24T14:30:00|LAURUSLABS 24APR2025|1|1|LAURUSLABS25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|41441|1|TATAELXSI|TATAELXSI25FEBFUT|FUTSTK|TATAELXSI-FUTSTK|2505800041441|6769.2|5538.45|4001|0.05|100|1|1100100003411|TATAELXSI|2025-02-27T14:30:00|TATAELXSI 27FEB2025|1|1|TATAELXSI25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|58958|1|BANKNIFTY|BANKNIFTY25MARFUT|FUTIDX|BANKNIFTY-FUTIDX|2508600058958|55006.6|45005.4|901|0.05|30|1|-1|Nifty Bank|2025-03-27T14:30:00|BANKNIFTY 27MAR2025|1|1|BANKNIFTY25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35232|1|AUROPHARMA|AUROPHARMA25MARFUT|FUTSTK|AUROPHARMA-FUTSTK|2508600035232|1268.3|1037.7|16501|0.05|550|1|1100100000275|AUROPHARMA|2025-03-27T14:30:00|AUROPHARMA 27MAR2025|1|1|AUROPHARMA25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|41287|1|RBLBANK|RBLBANK25FEBFUT|FUTSTK|RBLBANK-FUTSTK|2505800041287|177.1|144.9|150001|0.01|2500|1|1100100018391|RBLBANK|2025-02-27T14:30:00|RBLBANK 27FEB2025|1|1|RBLBANK25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73468|1|JSWENERGY|JSWENERGY25APRFUT|FUTSTK|JSWENERGY-FUTSTK|2511400073468|520.95|426.2|37501|0.05|750|1|1100100017869|JSWENERGY|2025-04-24T14:30:00|JSWENERGY 24APR2025|1|1|JSWENERGY25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39040|1|JINDALSTEL|JINDALSTEL25FEBFUT|FUTSTK|JINDALSTEL-FUTSTK|2505800039040|912.85|746.9|25001|0.05|625|1|1100100006733|JINDALSTEL|2025-02-27T14:30:00|JINDALSTEL 27FEB2025|1|1|JINDALSTEL25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35434|1|BERGEPAINT|BERGEPAINT25FEBFUT|FUTSTK|BERGEPAINT-FUTSTK|2505800035434|534.55|437.4|52801|0.05|1320|1|1100100000404|BERGEPAINT|2025-02-27T14:30:00|BERGEPAINT 27FEB2025|1|1|BERGEPAINT25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73521|1|PHOENIXLTD|PHOENIXLTD25FEBFUT|FUTSTK|PHOENIXLTD-FUTSTK|2505800073521|1760.4|1440.35|14001|0.05|350|1|1100100014552|PHOENIXLTD|2025-02-27T14:30:00|PHOENIXLTD 27FEB2025|1|1|PHOENIXLTD25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|40384|1|IDEA|IDEA25MARFUT|FUTSTK|IDEA-FUTSTK|2508600040384|9.34|7.64|1600001|0.01|40000|1|1100100014366|IDEA|2025-03-27T14:30:00|IDEA 27MAR2025|1|1|IDEA25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|41442|1|TATAMOTORS|TATAMOTORS25FEBFUT|FUTSTK|TATAMOTORS-FUTSTK|2505800041442|753.8|616.75|27501|0.05|550|1|1100100003456|TATAMOTORS|2025-02-27T14:30:00|TATAMOTORS 27FEB2025|1|1|TATAMOTORS25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|69094|1|BHARATFORG|BHARATFORG25APRFUT|FUTSTK|BHARATFORG-FUTSTK|2511400069094|1223.1|1000.75|20001|0.05|500|1|1100100000422|BHARATFORG|2025-04-24T14:30:00|BHARATFORG 24APR2025|1|1|BHARATFORG25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73492|1|MAXHEALTH|MAXHEALTH25APRFUT|FUTSTK|MAXHEALTH-FUTSTK|2511400073492|1119.4|915.85|21001|0.05|525|1|1100100022377|MAXHEALTH|2025-04-24T14:30:00|MAXHEALTH 24APR2025|1|1|MAXHEALTH25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73460|1|IRCTC|IRCTC25APRFUT|FUTSTK|IRCTC-FUTSTK|2511400073460|843.7|690.3|26251|0.05|875|1|1100100013611|IRCTC|2025-04-24T14:30:00|IRCTC 24APR2025|1|1|IRCTC25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73272|1|CHAMBLFERT|CHAMBLFERT25APRFUT|FUTSTK|CHAMBLFERT-FUTSTK|2511400073272|585.2|478.8|57001|0.05|1900|1|1100100000637|CHAMBLFERT|2025-04-24T14:30:00|CHAMBLFERT 24APR2025|1|1|CHAMBLFERT25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|41323|1|SUNPHARMA|SUNPHARMA25FEBFUT|FUTSTK|SUNPHARMA-FUTSTK|2505800041323|1869.9|1529.95|14001|0.05|350|1|1100100003351|SUNPHARMA|2025-02-27T14:30:00|SUNPHARMA 27FEB2025|1|1|SUNPHARMA25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73326|1|GODREJCP|GODREJCP25APRFUT|FUTSTK|GODREJCP-FUTSTK|2511400073326|1195.05|977.8|20001|0.05|500|1|1100100010099|GODREJCP|2025-04-24T14:30:00|GODREJCP 24APR2025|1|1|GODREJCP25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|54832|1|ADANIENSOL|ADANIENSOL25APRFUT|FUTSTK|ADANIENSOL-FUTSTK|2511400054832|842.5|689.35|31251|0.05|625|1|1100100010217|ADANIENSOL|2025-04-24T14:30:00|ADANIENSOL 24APR2025|1|1|ADANIENSOL25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35332|1|BALKRISIND|BALKRISIND25MARFUT|FUTSTK|BALKRISIND-FUTSTK|2508600035332|2914.75|2384.8|9001|0.05|300|1|1100100000335|BALKRISIND|2025-03-27T14:30:00|BALKRISIND 27MAR2025|1|1|BALKRISIND25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35213|1|ASHOKLEY|ASHOKLEY25MARFUT|FUTSTK|ASHOKLEY-FUTSTK|2508600035213|240.72|196.96|100001|0.01|2500|1|1100100000212|ASHOKLEY|2025-03-27T14:30:00|ASHOKLEY 27MAR2025|1|1|ASHOKLEY25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38915|1|IDFCFIRSTB|IDFCFIRSTB25FEBFUT|FUTSTK|IDFCFIRSTB-FUTSTK|2505800038915|68.56|56.1|375001|0.01|7500|1|1100100011184|IDFCFIRSTB|2025-02-27T14:30:00|IDFCFIRSTB 27FEB2025|1|1|IDFCFIRSTB25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43277|1|PERSISTENT|PERSISTENT25MARFUT|FUTSTK|PERSISTENT-FUTSTK|2508600043277|6283.05|5140.7|4001|0.05|100|1|1100100018365|PERSISTENT|2025-03-27T14:30:00|PERSISTENT 27MAR2025|1|1|PERSISTENT25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38877|1|ICICIGI|ICICIGI25FEBFUT|FUTSTK|ICICIGI-FUTSTK|2505800038877|1947|1593|12501|0.05|250|1|1100100021770|ICICIGI|2025-02-27T14:30:00|ICICIGI 27FEB2025|1|1|ICICIGI25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|41513|1|ULTRACEMCO|ULTRACEMCO25FEBFUT|FUTSTK|ULTRACEMCO-FUTSTK|2505800041513|12655.7|10354.65|2001|0.05|50|1|1100100011532|ULTRACEMCO|2025-02-27T14:30:00|ULTRACEMCO 27FEB2025|1|1|ULTRACEMCO25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35148|1|APOLLOTYRE|APOLLOTYRE25FEBFUT|FUTSTK|APOLLOTYRE-FUTSTK|2505800035148|455.1|372.35|51001|0.05|1700|1|1100100000163|APOLLOTYRE|2025-02-27T14:30:00|APOLLOTYRE 27FEB2025|1|1|APOLLOTYRE25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73329|1|GODREJPROP|GODREJPROP25APRFUT|FUTSTK|GODREJPROP-FUTSTK|2511400073329|2156|1764|9001|0.05|225|1|1100100017875|GODREJPROP|2025-04-24T14:30:00|GODREJPROP 24APR2025|1|1|GODREJPROP25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35401|1|BRITANNIA|BRITANNIA25MARFUT|FUTSTK|BRITANNIA-FUTSTK|2508600035401|5449.95|4459.05|5001|0.05|100|1|1100100000547|BRITANNIA|2025-03-27T14:30:00|BRITANNIA 27MAR2025|1|1|BRITANNIA25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35335|1|BANDHANBNK|BANDHANBNK25FEBFUT|FUTSTK|BANDHANBNK-FUTSTK|2505800035335|157.31|128.71|140001|0.01|2800|1|1100100002263|BANDHANBNK|2025-02-27T14:30:00|BANDHANBNK 27FEB2025|1|1|BANDHANBNK25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43450|1|YESBANK|YESBANK25MARFUT|FUTSTK|YESBANK-FUTSTK|2508600043450|20.12|16.46|1040001|0.01|26000|1|1100100011915|YESBANK|2025-03-27T14:30:00|YESBANK 27MAR2025|1|1|YESBANK25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43200|1|NATIONALUM|NATIONALUM25MARFUT|FUTSTK|NATIONALUM-FUTSTK|2508600043200|209.73|171.59|112501|0.01|3750|1|1100100006364|NATIONALUM|2025-03-27T14:30:00|NATIONALUM 27MAR2025|1|1|NATIONALUM25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73620|1|TATAMOTORS|TATAMOTORS25APRFUT|FUTSTK|TATAMOTORS-FUTSTK|2511400073620|762.75|624.1|27501|0.05|550|1|1100100003456|TATAMOTORS|2025-04-24T14:30:00|TATAMOTORS 24APR2025|1|1|TATAMOTORS25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|41452|1|TATASTEEL|TATASTEEL25FEBFUT|FUTSTK|TATASTEEL-FUTSTK|2505800041452|145.65|119.17|165001|0.01|5500|1|1100100003499|TATASTEEL|2025-02-27T14:30:00|TATASTEEL 27FEB2025|1|1|TATASTEEL25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73565|1|SHREECEM|SHREECEM25APRFUT|FUTSTK|SHREECEM-FUTSTK|2511400073565|31453.9|25735.05|1001|0.05|25|1|1100100003103|SHREECEM|2025-04-24T14:30:00|SHREECEM 24APR2025|1|1|SHREECEM25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73432|1|INDUSINDBK|INDUSINDBK25APRFUT|FUTSTK|INDUSINDBK-FUTSTK|2511400073432|1155.85|945.7|25001|0.05|500|1|1100100005258|INDUSINDBK|2025-04-24T14:30:00|INDUSINDBK 24APR2025|1|1|INDUSINDBK25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38271|1|DABUR|DABUR25FEBFUT|FUTSTK|DABUR-FUTSTK|2505800038271|578.95|473.7|50001|0.05|1250|1|1100100000772|DABUR|2025-02-27T14:30:00|DABUR 27FEB2025|1|1|DABUR25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|37492|1|CHOLAFIN|CHOLAFIN25FEBFUT|FUTSTK|CHOLAFIN-FUTSTK|2505800037492|1488.8|1218.15|18751|0.05|625|1|1100100000685|CHOLAFIN|2025-02-27T14:30:00|CHOLAFIN 27FEB2025|1|1|CHOLAFIN25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38881|1|ICICIPRULI|ICICIPRULI25FEBFUT|FUTSTK|ICICIPRULI-FUTSTK|2505800038881|638.4|522.35|37501|0.05|750|1|1100100018652|ICICIPRULI|2025-02-27T14:30:00|ICICIPRULI 27FEB2025|1|1|ICICIPRULI25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35350|1|BANKINDIA|BANKINDIA25MARFUT|FUTSTK|BANKINDIA-FUTSTK|2508600035350|113.7|93.02|241251|0.01|4825|1|1100100004745|BANKINDIA|2025-03-27T14:30:00|BANKINDIA 27MAR2025|1|1|BANKINDIA25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73308|1|EICHERMOT|EICHERMOT25APRFUT|FUTSTK|EICHERMOT-FUTSTK|2511400073308|5394|4413.25|5251|0.05|175|1|1100100000910|EICHERMOT|2025-04-24T14:30:00|EICHERMOT 24APR2025|1|1|EICHERMOT25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|40368|1|NMDC|NMDC25FEBFUT|FUTSTK|NMDC-FUTSTK|2505800040368|69.41|56.79|405001|0.01|13500|1|1100100015332|NMDC|2025-02-27T14:30:00|NMDC 27FEB2025|1|1|NMDC25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35450|1|BHARATFORG|BHARATFORG25FEBFUT|FUTSTK|BHARATFORG-FUTSTK|2505800035450|1209.75|989.8|20001|0.05|500|1|1100100000422|BHARATFORG|2025-02-27T14:30:00|BHARATFORG 27FEB2025|1|1|BHARATFORG25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|57246|1|ALKEM|ALKEM25APRFUT|FUTSTK|ALKEM-FUTSTK|2511400057246|5181|4239|5001|0.05|100|1|1100100011703|ALKEM|2025-04-24T14:30:00|ALKEM 24APR2025|1|1|ALKEM25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35245|1|AXISBANK|AXISBANK25MARFUT|FUTSTK|AXISBANK-FUTSTK|2508600035245|1115.9|913.05|25001|0.05|625|1|1100100005900|AXISBANK|2025-03-27T14:30:00|AXISBANK 27MAR2025|1|1|AXISBANK25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73528|1|POLYCAB|POLYCAB25APRFUT|FUTSTK|POLYCAB-FUTSTK|2511400073528|6292.9|5148.75|3751|0.05|125|1|1100100009590|POLYCAB|2025-04-24T14:30:00|POLYCAB 24APR2025|1|1|POLYCAB25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35025|1|ABFRL|ABFRL25MARFUT|FUTSTK|ABFRL-FUTSTK|2508600035025|285.3|233.45|78001|0.05|2600|1|1100100030108|ABFRL|2025-03-27T14:30:00|ABFRL 27MAR2025|1|1|ABFRL25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35816|1|DIXON|DIXON25MARFUT|FUTSTK|DIXON-FUTSTK|2508600035816|16095.6|13169.15|1501|0.05|50|1|1100100021690|DIXON|2025-03-27T14:30:00|DIXON 27MAR2025|1|1|DIXON25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|54446|1|FINNIFTY|FINNIFTY25APRFUT|FUTIDX|FINNIFTY-FUTIDX|2511400054446|25836.7|21139.15|1801|0.05|65|1|-1|Nifty Fin Service|2025-04-24T14:30:00|FINNIFTY 24APR2025|1|1|FINNIFTY25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73505|1|NCC|NCC25APRFUT|FUTSTK|NCC-FUTSTK|2511400073505|222.3|181.85|88751|0.05|1775|1|1100100002319|NCC|2025-04-24T14:30:00|NCC 24APR2025|1|1|NCC25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|40410|1|INDUSTOWER|INDUSTOWER25MARFUT|FUTSTK|INDUSTOWER-FUTSTK|2508600040410|385.55|315.45|68001|0.05|1700|1|1100100029135|INDUSTOWER|2025-03-27T14:30:00|INDUSTOWER 27MAR2025|1|1|INDUSTOWER25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43406|1|ULTRACEMCO|ULTRACEMCO25MARFUT|FUTSTK|ULTRACEMCO-FUTSTK|2508600043406|12703.35|10393.65|2001|0.05|50|1|1100100011532|ULTRACEMCO|2025-03-27T14:30:00|ULTRACEMCO 27MAR2025|1|1|ULTRACEMCO25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73577|1|TATACHEM|TATACHEM25APRFUT|FUTSTK|TATACHEM-FUTSTK|2511400073577|981.1|802.75|22001|0.05|550|1|1100100003405|TATACHEM|2025-04-24T14:30:00|TATACHEM 24APR2025|1|1|TATACHEM25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35060|1|ADANIGREEN|ADANIGREEN25MARFUT|FUTSTK|ADANIGREEN-FUTSTK|2508600035060|996.9|815.65|18751|0.05|375|1|1100100003563|ADANIGREEN|2025-03-27T14:30:00|ADANIGREEN 27MAR2025|1|1|ADANIGREEN25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38973|1|IPCALAB|IPCALAB25FEBFUT|FUTSTK|IPCALAB-FUTSTK|2505800038973|1568.3|1283.15|19501|0.05|650|1|1100100001633|IPCALAB|2025-02-27T14:30:00|IPCALAB 27FEB2025|1|1|IPCALAB25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43344|1|SAIL|SAIL25MARFUT|FUTSTK|SAIL-FUTSTK|2508600043344|116.63|95.43|200001|0.01|4000|1|1100100002963|SAIL|2025-03-27T14:30:00|SAIL 27MAR2025|1|1|SAIL25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38966|1|IOC|IOC25FEBFUT|FUTSTK|IOC-FUTSTK|2505800038966|132.67|108.55|195001|0.01|4875|1|1100100001624|IOC|2025-02-27T14:30:00|IOC 27FEB2025|1|1|IOC25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38746|1|HINDALCO|HINDALCO25FEBFUT|FUTSTK|HINDALCO-FUTSTK|2505800038746|659.7|539.75|42001|0.05|1400|1|1100100001363|HINDALCO|2025-02-27T14:30:00|HINDALCO 27FEB2025|1|1|HINDALCO25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|40861|1|PERSISTENT|PERSISTENT25FEBFUT|FUTSTK|PERSISTENT-FUTSTK|2505800040861|6267.35|5127.8|4001|0.05|100|1|1100100018365|PERSISTENT|2025-02-27T14:30:00|PERSISTENT 27FEB2025|1|1|PERSISTENT25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39699|1|NHPC|NHPC25FEBFUT|FUTSTK|NHPC-FUTSTK|2505800039699|79.98|65.44|256001|0.01|6400|1|1100100017400|NHPC|2025-02-27T14:30:00|NHPC 27FEB2025|1|1|NHPC25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35525|1|FINNIFTY|FINNIFTY25FEBFUT|FUTIDX|FINNIFTY-FUTIDX|2505800035525|25633.7|20973.05|1801|0.05|65|1|-1|Nifty Fin Service|2025-02-27T14:30:00|FINNIFTY 27FEB2025|1|1|FINNIFTY25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|37352|1|GODREJPROP|GODREJPROP25MARFUT|FUTSTK|GODREJPROP-FUTSTK|2508600037352|2143.75|1754|9001|0.05|225|1|1100100017875|GODREJPROP|2025-03-27T14:30:00|GODREJPROP 27MAR2025|1|1|GODREJPROP25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43212|1|NCC|NCC25MARFUT|FUTSTK|NCC-FUTSTK|2508600043212|216.25|176.9|88751|0.05|1775|1|1100100002319|NCC|2025-03-27T14:30:00|NCC 27MAR2025|1|1|NCC25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39195|1|MANAPPURAM|MANAPPURAM25FEBFUT|FUTSTK|MANAPPURAM-FUTSTK|2505800039195|210.89|172.55|120001|0.01|3000|1|1100100019061|MANAPPURAM|2025-02-27T14:30:00|MANAPPURAM 27FEB2025|1|1|MANAPPURAM25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43312|1|POLICYBZR|POLICYBZR25MARFUT|FUTSTK|POLICYBZR-FUTSTK|2508600043312|1767.55|1446.2|13001|0.05|325|1|1100100006656|POLICYBZR|2025-03-27T14:30:00|POLICYBZR 27MAR2025|1|1|POLICYBZR25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73535|1|RBLBANK|RBLBANK25APRFUT|FUTSTK|RBLBANK-FUTSTK|2511400073535|178.74|146.24|150001|0.01|2500|1|1100100018391|RBLBANK|2025-04-24T14:30:00|RBLBANK 24APR2025|1|1|RBLBANK25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35215|1|ASIANPAINT|ASIANPAINT25MARFUT|FUTSTK|ASIANPAINT-FUTSTK|2508600035215|2469.85|2020.8|10001|0.05|200|1|1100100000236|ASIANPAINT|2025-03-27T14:30:00|ASIANPAINT 27MAR2025|1|1|ASIANPAINT25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38529|1|GLENMARK|GLENMARK25FEBFUT|FUTSTK|GLENMARK-FUTSTK|2505800038529|1550.85|1268.9|16251|0.05|325|1|1100100007406|GLENMARK|2025-02-27T14:30:00|GLENMARK 27FEB2025|1|1|GLENMARK25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39207|1|MCX|MCX25FEBFUT|FUTSTK|MCX-FUTSTK|2505800039207|6128.35|5014.1|4001|0.05|100|1|1100100031181|MCX|2025-02-27T14:30:00|MCX 27FEB2025|1|1|MCX25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|40484|1|PEL|PEL25FEBFUT|FUTSTK|PEL-FUTSTK|2505800040484|1079.8|883.45|22501|0.05|750|1|1100100002412|PEL|2025-02-27T14:30:00|PEL 27FEB2025|1|1|PEL25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|69080|1|ASTRAL|ASTRAL25APRFUT|FUTSTK|ASTRAL-FUTSTK|2511400069080|1559.55|1276|14681|0.05|367|1|1100100014418|ASTRAL|2025-04-24T14:30:00|ASTRAL 24APR2025|1|1|ASTRAL25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43400|1|TITAN|TITAN25MARFUT|FUTSTK|TITAN-FUTSTK|2508600043400|3613.45|2956.5|7001|0.05|175|1|1100100003506|TITAN|2025-03-27T14:30:00|TITAN 27MAR2025|1|1|TITAN25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43267|1|PAGEIND|PAGEIND25MARFUT|FUTSTK|PAGEIND-FUTSTK|2508600043267|45265.65|37035.5|601|0.05|15|1|1100100014413|PAGEIND|2025-03-27T14:30:00|PAGEIND 27MAR2025|1|1|PAGEIND25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|69092|1|BEL|BEL25APRFUT|FUTSTK|BEL-FUTSTK|2511400069092|289.1|236.55|85501|0.05|2850|1|1100100000383|BEL|2025-04-24T14:30:00|BEL 24APR2025|1|1|BEL25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35333|1|BANDHANBNK|BANDHANBNK25MARFUT|FUTSTK|BANDHANBNK-FUTSTK|2508600035333|158.28|129.5|140001|0.01|2800|1|1100100002263|BANDHANBNK|2025-03-27T14:30:00|BANDHANBNK 27MAR2025|1|1|BANDHANBNK25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73263|1|BSOFT|BSOFT25APRFUT|FUTSTK|BSOFT-FUTSTK|2511400073263|561.15|459.1|40001|0.05|1000|1|1100100006994|BSOFT|2025-04-24T14:30:00|BSOFT 24APR2025|1|1|BSOFT25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|69087|1|BAJFINANCE|BAJFINANCE25APRFUT|FUTSTK|BAJFINANCE-FUTSTK|2511400069087|9181.6|7512.25|3751|0.05|125|1|1100100000317|BAJFINANCE|2025-04-24T14:30:00|BAJFINANCE 24APR2025|1|1|BAJFINANCE25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|37309|1|GLENMARK|GLENMARK25MARFUT|FUTSTK|GLENMARK-FUTSTK|2508600037309|1559.6|1276.05|16251|0.05|325|1|1100100007406|GLENMARK|2025-03-27T14:30:00|GLENMARK 27MAR2025|1|1|GLENMARK25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39929|1|ICICIGI|ICICIGI25MARFUT|FUTSTK|ICICIGI-FUTSTK|2508600039929|1958.8|1602.65|12501|0.05|250|1|1100100021770|ICICIGI|2025-03-27T14:30:00|ICICIGI 27MAR2025|1|1|ICICIGI25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39184|1|LICI|LICI25FEBFUT|FUTSTK|LICI-FUTSTK|2505800039184|861.3|704.7|28751|0.05|575|1|1100100009480|LICI|2025-02-27T14:30:00|LICI 27FEB2025|1|1|LICI25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|69095|1|BHARTIARTL|BHARTIARTL25APRFUT|FUTSTK|BHARTIARTL-FUTSTK|2511400069095|1904.75|1558.4|14251|0.05|475|1|1100100010604|BHARTIARTL|2025-04-24T14:30:00|BHARTIARTL 24APR2025|1|1|BHARTIARTL25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73311|1|FEDERALBNK|FEDERALBNK25APRFUT|FUTSTK|FEDERALBNK-FUTSTK|2511400073311|204.55|167.36|150001|0.01|5000|1|1100100001023|FEDERALBNK|2025-04-24T14:30:00|FEDERALBNK 24APR2025|1|1|FEDERALBNK25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73633|1|TORNTPHARM|TORNTPHARM25APRFUT|FUTSTK|TORNTPHARM-FUTSTK|2511400073633|3408.75|2789|7501|0.05|250|1|1100100003518|TORNTPHARM|2025-04-24T14:30:00|TORNTPHARM 24APR2025|1|1|TORNTPHARM25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38107|1|COROMANDEL|COROMANDEL25FEBFUT|FUTSTK|COROMANDEL-FUTSTK|2505800038107|2033.8|1664.05|14001|0.05|350|1|1100100000739|COROMANDEL|2025-02-27T14:30:00|COROMANDEL 27FEB2025|1|1|COROMANDEL25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|37513|1|COFORGE|COFORGE25FEBFUT|FUTSTK|COFORGE-FUTSTK|2505800037513|8837.6|7230.75|2251|0.05|75|1|1100100011543|COFORGE|2025-02-27T14:30:00|COFORGE 27FEB2025|1|1|COFORGE25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35247|1|BAJAJ-AUTO|BAJAJ-AUTO25MARFUT|FUTSTK|BAJAJ-AUTO-FUTSTK|2508600035247|9656.05|7900.4|3001|0.05|75|1|1100100016669|BAJAJ-AUTO|2025-03-27T14:30:00|BAJAJ-AUTO 27MAR2025|1|1|BAJAJ-AUTO25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|40385|1|IDFCFIRSTB|IDFCFIRSTB25MARFUT|FUTSTK|IDFCFIRSTB-FUTSTK|2508600040385|68.75|56.25|375001|0.01|7500|1|1100100011184|IDFCFIRSTB|2025-03-27T14:30:00|IDFCFIRSTB 27MAR2025|1|1|IDFCFIRSTB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|54455|1|ABB|ABB25APRFUT|FUTSTK|ABB-FUTSTK|2511400054455|6071.05|4967.2|3751|0.05|125|1|1100100000013|ABB|2025-04-24T14:30:00|ABB 24APR2025|1|1|ABB25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43120|1|LT|LT25MARFUT|FUTSTK|LT-FUTSTK|2508600043120|3647.85|2984.6|6001|0.05|150|1|1100100011483|LT|2025-03-27T14:30:00|LT 27MAR2025|1|1|LT25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|65552|1|ANGELONE|ANGELONE25APRFUT|FUTSTK|ANGELONE-FUTSTK|2511400065552|2416.9|1977.45|8001|0.05|200|1|1100100000324|ANGELONE|2025-04-24T14:30:00|ANGELONE 24APR2025|1|1|ANGELONE25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|65553|1|APLAPOLLO|APLAPOLLO25APRFUT|FUTSTK|APLAPOLLO-FUTSTK|2511400065553|1497.5|1225.25|14001|0.05|350|1|1100100025780|APLAPOLLO|2025-04-24T14:30:00|APLAPOLLO 24APR2025|1|1|APLAPOLLO25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73485|1|LTIM|LTIM25APRFUT|FUTSTK|LTIM-FUTSTK|2511400073485|6323.55|5173.8|4501|0.05|150|1|1100100017818|LTIM|2025-04-24T14:30:00|LTIM 24APR2025|1|1|LTIM25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35000|1|MIDCPNIFTY|MIDCPNIFTY25MARFUT|FUTIDX|MIDCPNIFTY-FUTIDX|2508600035000|12610.8|10317.95|2801|0.05|120|1|-1|NIFTY MID SELECT|2025-03-27T14:30:00|MIDCPNIFTY 27MAR2025|1|1|MIDCPNIFTY25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43199|1|MUTHOOTFIN|MUTHOOTFIN25MARFUT|FUTSTK|MUTHOOTFIN-FUTSTK|2508600043199|2404.5|1967.35|11001|0.05|275|1|1100100023650|MUTHOOTFIN|2025-03-27T14:30:00|MUTHOOTFIN 27MAR2025|1|1|MUTHOOTFIN25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|40862|1|PETRONET|PETRONET25FEBFUT|FUTSTK|PETRONET-FUTSTK|2505800040862|332.55|272.1|75001|0.05|1500|1|1100100011351|PETRONET|2025-02-27T14:30:00|PETRONET 27FEB2025|1|1|PETRONET25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73627|1|TCS|TCS25APRFUT|FUTSTK|TCS-FUTSTK|2511400073627|4410.2|3608.35|5251|0.05|175|1|1100100011536|TCS|2025-04-24T14:30:00|TCS 24APR2025|1|1|TCS25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|54449|1|MIDCPNIFTY|MIDCPNIFTY25APRFUT|FUTIDX|MIDCPNIFTY-FUTIDX|2511400054449|12617|10323|2801|0.05|120|1|-1|NIFTY MID SELECT|2025-04-24T14:30:00|MIDCPNIFTY 24APR2025|1|1|MIDCPNIFTY25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73486|1|LUPIN|LUPIN25APRFUT|FUTSTK|LUPIN-FUTSTK|2511400073486|2252.95|1843.3|12751|0.05|425|1|1100100010440|LUPIN|2025-04-24T14:30:00|LUPIN 24APR2025|1|1|LUPIN25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43113|1|LICHSGFIN|LICHSGFIN25MARFUT|FUTSTK|LICHSGFIN-FUTSTK|2508600043113|602.8|493.2|40001|0.05|1000|1|1100100001997|LICHSGFIN|2025-03-27T14:30:00|LICHSGFIN 27MAR2025|1|1|LICHSGFIN25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43417|1|UNITDSPR|UNITDSPR25MARFUT|FUTSTK|UNITDSPR-FUTSTK|2508600043417|1547.4|1266.05|14001|0.05|350|1|1100100010447|UNITDSPR|2025-03-27T14:30:00|UNITDSPR 27MAR2025|1|1|UNITDSPR25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38885|1|IDEA|IDEA25FEBFUT|FUTSTK|IDEA-FUTSTK|2505800038885|9.27|7.59|1600001|0.01|40000|1|1100100014366|IDEA|2025-02-27T14:30:00|IDEA 27FEB2025|1|1|IDEA25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73259|1|BRITANNIA|BRITANNIA25APRFUT|FUTSTK|BRITANNIA-FUTSTK|2511400073259|5443.1|4453.45|5001|0.05|100|1|1100100000547|BRITANNIA|2025-04-24T14:30:00|BRITANNIA 24APR2025|1|1|BRITANNIA25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73371|1|HUDCO|HUDCO25APRFUT|FUTSTK|HUDCO-FUTSTK|2511400073371|213.92|175.02|97001|0.01|2425|1|1100100020825|HUDCO|2025-04-24T14:30:00|HUDCO 24APR2025|1|1|HUDCO25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73348|1|HINDALCO|HINDALCO25APRFUT|FUTSTK|HINDALCO-FUTSTK|2511400073348|667.15|545.85|42001|0.05|1400|1|1100100001363|HINDALCO|2025-04-24T14:30:00|HINDALCO 24APR2025|1|1|HINDALCO25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35310|1|AXISBANK|AXISBANK25FEBFUT|FUTSTK|AXISBANK-FUTSTK|2505800035310|1109.3|907.65|25001|0.05|625|1|1100100005900|AXISBANK|2025-02-27T14:30:00|AXISBANK 27FEB2025|1|1|AXISBANK25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35080|1|ALKEM|ALKEM25FEBFUT|FUTSTK|ALKEM-FUTSTK|2505800035080|5153.85|4216.8|5001|0.05|100|1|1100100011703|ALKEM|2025-02-27T14:30:00|ALKEM 27FEB2025|1|1|ALKEM25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35411|1|CESC|CESC25MARFUT|FUTSTK|CESC-FUTSTK|2508600035411|141.9|116.1|146251|0.01|2925|1|1100100000628|CESC|2025-03-27T14:30:00|CESC 27MAR2025|1|1|CESC25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|69088|1|BALKRISIND|BALKRISIND25APRFUT|FUTSTK|BALKRISIND-FUTSTK|2511400069088|2938.75|2404.4|9001|0.05|300|1|1100100000335|BALKRISIND|2025-04-24T14:30:00|BALKRISIND 24APR2025|1|1|BALKRISIND25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38098|1|COLPAL|COLPAL25FEBFUT|FUTSTK|COLPAL-FUTSTK|2505800038098|2790.5|2283.15|8751|0.05|175|1|1100100015141|COLPAL|2025-02-27T14:30:00|COLPAL 27FEB2025|1|1|COLPAL25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38570|1|GODREJCP|GODREJCP25FEBFUT|FUTSTK|GODREJCP-FUTSTK|2505800038570|1185.05|969.6|20001|0.05|500|1|1100100010099|GODREJCP|2025-02-27T14:30:00|GODREJCP 27FEB2025|1|1|GODREJCP25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35769|1|CYIENT|CYIENT25MARFUT|FUTSTK|CYIENT-FUTSTK|2508600035769|1578.7|1291.65|15001|0.05|300|1|1100100005748|CYIENT|2025-03-27T14:30:00|CYIENT 27MAR2025|1|1|CYIENT25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73428|1|INDHOTEL|INDHOTEL25APRFUT|FUTSTK|INDHOTEL-FUTSTK|2511400073428|816.9|668.35|30001|0.05|1000|1|1100100001512|INDHOTEL|2025-04-24T14:30:00|INDHOTEL 24APR2025|1|1|INDHOTEL25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35001|1|NIFTY|NIFTY25MARFUT|FUTIDX|NIFTY-FUTIDX|2508600035001|25592.4|20939.25|1801|0.05|75|1|-1|Nifty 50|2025-03-27T14:30:00|NIFTY 27MAR2025|1|1|NIFTY25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|41505|1|TORNTPHARM|TORNTPHARM25FEBFUT|FUTSTK|TORNTPHARM-FUTSTK|2505800041505|3377.45|2763.4|7501|0.05|250|1|1100100003518|TORNTPHARM|2025-02-27T14:30:00|TORNTPHARM 27FEB2025|1|1|TORNTPHARM25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|40485|1|IRFC|IRFC25MARFUT|FUTSTK|IRFC-FUTSTK|2508600040485|128.41|105.07|141001|0.01|3525|1|1100100002029|IRFC|2025-03-27T14:30:00|IRFC 27MAR2025|1|1|IRFC25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39345|1|HAVELLS|HAVELLS25MARFUT|FUTSTK|HAVELLS-FUTSTK|2508600039345|1694.8|1386.65|15001|0.05|500|1|1100100009819|HAVELLS|2025-03-27T14:30:00|HAVELLS 27MAR2025|1|1|HAVELLS25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35361|1|BIOCON|BIOCON25MARFUT|FUTSTK|BIOCON-FUTSTK|2508600035361|395.95|324|75001|0.05|2500|1|1100100011373|BIOCON|2025-03-27T14:30:00|BIOCON 27MAR2025|1|1|BIOCON25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73275|1|COALINDIA|COALINDIA25APRFUT|FUTSTK|COALINDIA-FUTSTK|2511400073275|402.35|329.2|63001|0.05|1050|1|1100100020374|COALINDIA|2025-04-24T14:30:00|COALINDIA 24APR2025|1|1|COALINDIA25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39123|1|JUBLFOOD|JUBLFOOD25FEBFUT|FUTSTK|JUBLFOOD-FUTSTK|2505800039123|706.6|578.15|37501|0.05|1250|1|1100100018096|JUBLFOOD|2025-02-27T14:30:00|JUBLFOOD 27FEB2025|1|1|JUBLFOOD25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|36713|1|091NSETEST|091NSETEST36DECFUT|FUTSTK|091NSETEST-FUTSTK|2633200036713|220|180|100001|0.05|50|1|1100100014769|091NSETEST|2036-11-27T14:30:00|091NSETEST 27NOV2036|1|1|091NSETEST36DECFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73501|1|NAUKRI|NAUKRI25APRFUT|FUTSTK|NAUKRI-FUTSTK|2511400073501|8431.45|6898.5|3001|0.05|75|1|1100100013751|NAUKRI|2025-04-24T14:30:00|NAUKRI 24APR2025|1|1|NAUKRI25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|40876|1|PIDILITIND|PIDILITIND25FEBFUT|FUTSTK|PIDILITIND-FUTSTK|2505800040876|3123.45|2555.55|7501|0.05|250|1|1100100002664|PIDILITIND|2025-02-27T14:30:00|PIDILITIND 27FEB2025|1|1|PIDILITIND25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35817|1|DLF|DLF25MARFUT|FUTSTK|DLF-FUTSTK|2508600035817|755.15|617.85|33001|0.05|825|1|1100100014732|DLF|2025-03-27T14:30:00|DLF 27MAR2025|1|1|DLF25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|41617|1|KALYANKJIL|KALYANKJIL25MARFUT|FUTSTK|KALYANKJIL-FUTSTK|2508600041617|548|448.35|31001|0.05|775|1|1100100002955|KALYANKJIL|2025-03-27T14:30:00|KALYANKJIL 27MAR2025|1|1|KALYANKJIL25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73496|1|MOTHERSON|MOTHERSON25APRFUT|FUTSTK|MOTHERSON-FUTSTK|2511400073496|143.61|117.5|142001|0.01|3550|1|1100100004204|MOTHERSON|2025-04-24T14:30:00|MOTHERSON 24APR2025|1|1|MOTHERSON25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39696|1|NESTLEIND|NESTLEIND25FEBFUT|FUTSTK|NESTLEIND-FUTSTK|2505800039696|2416.6|1977.25|10001|0.05|200|1|1100100017963|NESTLEIND|2025-02-27T14:30:00|NESTLEIND 27FEB2025|1|1|NESTLEIND25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39209|1|MFSL|MFSL25FEBFUT|FUTSTK|MFSL-FUTSTK|2505800039209|1201.1|982.75|24001|0.05|800|1|1100100002142|MFSL|2025-02-27T14:30:00|MFSL 27FEB2025|1|1|MFSL25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38583|1|HAL|HAL25FEBFUT|FUTSTK|HAL-FUTSTK|2505800038583|3939.45|3223.2|6001|0.05|150|1|1100100002303|HAL|2025-02-27T14:30:00|HAL 27FEB2025|1|1|HAL25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|54452|1|NIFTY|NIFTY25APRFUT|FUTIDX|NIFTY-FUTIDX|2511400054452|25752.25|21070|1801|0.05|75|1|-1|Nifty 50|2025-04-24T14:30:00|NIFTY 24APR2025|1|1|NIFTY25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39179|1|LALPATHLAB|LALPATHLAB25FEBFUT|FUTSTK|LALPATHLAB-FUTSTK|2505800039179|2949.65|2413.35|7501|0.05|150|1|1100100011654|LALPATHLAB|2025-02-27T14:30:00|LALPATHLAB 27FEB2025|1|1|LALPATHLAB25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|41576|1|JKCEMENT|JKCEMENT25MARFUT|FUTSTK|JKCEMENT-FUTSTK|2508600041576|5198.95|4253.7|5001|0.05|125|1|1100100013270|JKCEMENT|2025-03-27T14:30:00|JKCEMENT 27MAR2025|1|1|JKCEMENT25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|54445|1|BANKNIFTY|BANKNIFTY25APRFUT|FUTIDX|BANKNIFTY-FUTIDX|2511400054445|55405.2|45331.55|901|0.05|30|1|-1|Nifty Bank|2025-04-24T14:30:00|BANKNIFTY 24APR2025|1|1|BANKNIFTY25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73518|1|PERSISTENT|PERSISTENT25APRFUT|FUTSTK|PERSISTENT-FUTSTK|2511400073518|6355.6|5200.05|4001|0.05|100|1|1100100018365|PERSISTENT|2025-04-24T14:30:00|PERSISTENT 24APR2025|1|1|PERSISTENT25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35017|1|ABCAPITAL|ABCAPITAL25FEBFUT|FUTSTK|ABCAPITAL-FUTSTK|2505800035017|175.03|143.21|135001|0.01|2700|1|1100100021614|ABCAPITAL|2025-02-27T14:30:00|ABCAPITAL 27FEB2025|1|1|ABCAPITAL25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|69096|1|BHEL|BHEL25APRFUT|FUTSTK|BHEL-FUTSTK|2511400069096|221.57|181.29|105001|0.01|2625|1|1100100000438|BHEL|2025-04-24T14:30:00|BHEL 24APR2025|1|1|BHEL25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73481|1|LICI|LICI25APRFUT|FUTSTK|LICI-FUTSTK|2511400073481|869.95|711.8|28751|0.05|575|1|1100100009480|LICI|2025-04-24T14:30:00|LICI 24APR2025|1|1|LICI25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39193|1|M&M|M&M25FEBFUT|FUTSTK|M&M-FUTSTK|2505800039193|3294.45|2695.5|7001|0.05|175|1|1100100002031|M&M|2025-02-27T14:30:00|M&M 27FEB2025|1|1|M&M25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35571|1|CUMMINSIND|CUMMINSIND25MARFUT|FUTSTK|CUMMINSIND-FUTSTK|2508600035571|3093.95|2531.4|7501|0.05|150|1|1100100001901|CUMMINSIND|2025-03-27T14:30:00|CUMMINSIND 27MAR2025|1|1|CUMMINSIND25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35839|1|CDSL|CDSL25FEBFUT|FUTSTK|CDSL-FUTSTK|2505800035839|1363.9|1115.95|14001|0.05|350|1|1100100021174|CDSL|2025-02-27T14:30:00|CDSL 27FEB2025|1|1|CDSL25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38109|1|CUB|CUB25FEBFUT|FUTSTK|CUB-FUTSTK|2505800038109|183.88|150.44|150001|0.01|5000|1|1100100005701|CUB|2025-02-27T14:30:00|CUB 27FEB2025|1|1|CUB25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|36702|1|071NSETEST|071NSETEST36DECFUT|FUTSTK|071NSETEST-FUTSTK|2633200036702|220|180|100001|0.05|50|1|1100100014764|071NSETEST|2036-11-27T14:30:00|071NSETEST 27NOV2036|1|1|071NSETEST36DECFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35329|1|BAJFINANCE|BAJFINANCE25FEBFUT|FUTSTK|BAJFINANCE-FUTSTK|2505800035329|9071.9|7422.45|3751|0.05|125|1|1100100000317|BAJFINANCE|2025-02-27T14:30:00|BAJFINANCE 27FEB2025|1|1|BAJFINANCE25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35422|1|BATAINDIA|BATAINDIA25FEBFUT|FUTSTK|BATAINDIA-FUTSTK|2505800035422|1494.45|1222.7|18751|0.05|375|1|1100100000371|BATAINDIA|2025-02-27T14:30:00|BATAINDIA 27FEB2025|1|1|BATAINDIA25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38108|1|CROMPTON|CROMPTON25FEBFUT|FUTSTK|CROMPTON-FUTSTK|2505800038108|375.2|306.95|54001|0.05|1800|1|1100100017094|CROMPTON|2025-02-27T14:30:00|CROMPTON 27FEB2025|1|1|CROMPTON25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43451|1|ZOMATO|ZOMATO25MARFUT|FUTSTK|ZOMATO-FUTSTK|2508600043451|238.15|194.85|80001|0.01|2000|1|1100100005097|ZOMATO|2025-03-27T14:30:00|ZOMATO 27MAR2025|1|1|ZOMATO25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73578|1|TATACOMM|TATACOMM25APRFUT|FUTSTK|TATACOMM-FUTSTK|2511400073578|1702.35|1392.8|12501|0.05|250|1|1100100003721|TATACOMM|2025-04-24T14:30:00|TATACOMM 24APR2025|1|1|TATACOMM25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43122|1|LTIM|LTIM25MARFUT|FUTSTK|LTIM-FUTSTK|2508600043122|6294.9|5150.35|4501|0.05|150|1|1100100017818|LTIM|2025-03-27T14:30:00|LTIM 27MAR2025|1|1|LTIM25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73523|1|PHOENIXLTD|PHOENIXLTD25APRFUT|FUTSTK|PHOENIXLTD-FUTSTK|2511400073523|1782.45|1458.4|14001|0.05|350|1|1100100014552|PHOENIXLTD|2025-04-24T14:30:00|PHOENIXLTD 24APR2025|1|1|PHOENIXLTD25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35212|1|APOLLOTYRE|APOLLOTYRE25MARFUT|FUTSTK|APOLLOTYRE-FUTSTK|2508600035212|451.15|369.1|51001|0.05|1700|1|1100100000163|APOLLOTYRE|2025-03-27T14:30:00|APOLLOTYRE 27MAR2025|1|1|APOLLOTYRE25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38291|1|DALBHARAT|DALBHARAT25FEBFUT|FUTSTK|DALBHARAT-FUTSTK|2505800038291|1985.3|1624.35|13751|0.05|275|1|1100100008075|DALBHARAT|2025-02-27T14:30:00|DALBHARAT 27FEB2025|1|1|DALBHARAT25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39215|1|MOTHERSON|MOTHERSON25FEBFUT|FUTSTK|MOTHERSON-FUTSTK|2505800039215|141.86|116.06|142001|0.01|3550|1|1100100004204|MOTHERSON|2025-02-27T14:30:00|MOTHERSON 27FEB2025|1|1|MOTHERSON25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35362|1|BOSCHLTD|BOSCHLTD25MARFUT|FUTSTK|BOSCHLTD-FUTSTK|2508600035362|30317.35|24805.1|751|0.05|25|1|1100100002181|BOSCHLTD|2025-03-27T14:30:00|BOSCHLTD 27MAR2025|1|1|BOSCHLTD25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35453|1|BHEL|BHEL25FEBFUT|FUTSTK|BHEL-FUTSTK|2505800035453|219.2|179.34|105001|0.01|2625|1|1100100000438|BHEL|2025-02-27T14:30:00|BHEL 27FEB2025|1|1|BHEL25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73579|1|TATACONSUM|TATACONSUM25APRFUT|FUTSTK|TATACONSUM-FUTSTK|2511400073579|1146.5|938.05|22801|0.05|456|1|1100100003432|TATACONSUM|2025-04-24T14:30:00|TATACONSUM 24APR2025|1|1|TATACONSUM25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|41310|1|SHRIRAMFIN|SHRIRAMFIN25FEBFUT|FUTSTK|SHRIRAMFIN-FUTSTK|2505800041310|603.2|493.55|37501|0.05|750|1|1100100004306|SHRIRAMFIN|2025-02-27T14:30:00|SHRIRAMFIN 27FEB2025|1|1|SHRIRAMFIN25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|54834|1|ADANIGREEN|ADANIGREEN25APRFUT|FUTSTK|ADANIGREEN-FUTSTK|2511400054834|994.3|813.55|18751|0.05|375|1|1100100003563|ADANIGREEN|2025-04-24T14:30:00|ADANIGREEN 24APR2025|1|1|ADANIGREEN25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43339|1|RBLBANK|RBLBANK25MARFUT|FUTSTK|RBLBANK-FUTSTK|2508600043339|177.09|144.89|150001|0.01|2500|1|1100100018391|RBLBANK|2025-03-27T14:30:00|RBLBANK 27MAR2025|1|1|RBLBANK25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|54835|1|ADANIPORTS|ADANIPORTS25APRFUT|FUTSTK|ADANIPORTS-FUTSTK|2511400054835|1261.05|1031.8|20001|0.05|400|1|1100100015083|ADANIPORTS|2025-04-24T14:30:00|ADANIPORTS 24APR2025|1|1|ADANIPORTS25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35295|1|AUBANK|AUBANK25FEBFUT|FUTSTK|AUBANK-FUTSTK|2505800035295|611.75|500.5|40001|0.05|1000|1|1100100021238|AUBANK|2025-02-27T14:30:00|AUBANK 27FEB2025|1|1|AUBANK25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35823|1|CANBK|CANBK25FEBFUT|FUTSTK|CANBK-FUTSTK|2505800035823|99.99|81.81|270001|0.01|6750|1|1100100010794|CANBK|2025-02-27T14:30:00|CANBK 27FEB2025|1|1|CANBK25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73478|1|KPITTECH|KPITTECH25APRFUT|FUTSTK|KPITTECH-FUTSTK|2511400073478|1507.4|1233.35|16001|0.05|400|1|1100100009683|KPITTECH|2025-04-24T14:30:00|KPITTECH 24APR2025|1|1|KPITTECH25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39354|1|HDFCBANK|HDFCBANK25MARFUT|FUTSTK|HDFCBANK-FUTSTK|2508600039354|1895.6|1550.95|16501|0.05|550|1|1100100001333|HDFCBANK|2025-03-27T14:30:00|HDFCBANK 27MAR2025|1|1|HDFCBANK25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43396|1|TECHM|TECHM25MARFUT|FUTSTK|TECHM-FUTSTK|2508600043396|1854.3|1517.15|18001|0.05|600|1|1100100013538|TECHM|2025-03-27T14:30:00|TECHM 27MAR2025|1|1|TECHM25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|38579|1|GUJGASLTD|GUJGASLTD25FEBFUT|FUTSTK|GUJGASLTD-FUTSTK|2505800038579|448.4|366.85|50001|0.05|1250|1|1100100010599|GUJGASLTD|2025-02-27T14:30:00|GUJGASLTD 27FEB2025|1|1|GUJGASLTD25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73671|1|ULTRACEMCO|ULTRACEMCO25APRFUT|FUTSTK|ULTRACEMCO-FUTSTK|2511400073671|12721.5|10408.5|2001|0.05|50|1|1100100011532|ULTRACEMCO|2025-04-24T14:30:00|ULTRACEMCO 24APR2025|1|1|ULTRACEMCO25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|39020|1|IRFC|IRFC25FEBFUT|FUTSTK|IRFC-FUTSTK|2505800039020|134.61|110.13|141001|0.01|3525|1|1100100002029|IRFC|2025-02-27T14:30:00|IRFC 27FEB2025|1|1|IRFC25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73525|1|PIIND|PIIND25APRFUT|FUTSTK|PIIND-FUTSTK|2511400073525|3739.3|3059.45|6251|0.05|125|1|1100100024184|PIIND|2025-04-24T14:30:00|PIIND 24APR2025|1|1|PIIND25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|41301|1|SBICARD|SBICARD25FEBFUT|FUTSTK|SBICARD-FUTSTK|2505800041301|896.25|733.3|32001|0.05|800|1|1100100017971|SBICARD|2025-02-27T14:30:00|SBICARD 27FEB2025|1|1|SBICARD25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|41548|1|VEDL|VEDL25FEBFUT|FUTSTK|VEDL-FUTSTK|2505800041548|465.6|380.95|46001|0.05|1150|1|1100100003063|VEDL|2025-02-27T14:30:00|VEDL 27FEB2025|1|1|VEDL25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35457|1|BRITANNIA|BRITANNIA25FEBFUT|FUTSTK|BRITANNIA-FUTSTK|2505800035457|5430.6|4443.25|5001|0.05|100|1|1100100000547|BRITANNIA|2025-02-27T14:30:00|BRITANNIA 27FEB2025|1|1|BRITANNIA25FEBFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|43195|1|MPHASIS|MPHASIS25MARFUT|FUTSTK|MPHASIS-FUTSTK|2508600043195|2966.45|2427.1|8251|0.05|275|1|1100100004503|MPHASIS|2025-03-27T14:30:00|MPHASIS 27MAR2025|1|1|MPHASIS25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|73469|1|JSWSTEEL|JSWSTEEL25APRFUT|FUTSTK|JSWSTEEL-FUTSTK|2511400073469|1065.45|871.7|27001|0.05|675|1|1100100011723|JSWSTEEL|2025-04-24T14:30:00|JSWSTEEL 24APR2025|1|1|JSWSTEEL25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|35793|1|DABUR|DABUR25MARFUT|FUTSTK|DABUR-FUTSTK|2508600035793|582.05|476.2|50001|0.05|1250|1|1100100000772|DABUR|2025-03-27T14:30:00|DABUR 27MAR2025|1|1|DABUR25MARFUT
# ...
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10037350|4|JIOFIN|JIOFIN25FEB25MARFUT|FUTSTK|JIOFIN-FUTSTK|2100110037350|5.71|-5.71|82501|0.01|1650|1|-1||2025-02-27T14:30:00|JIOFIN 27FEB27MAR SPD|1|1|JIOFIN25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9953474|4|HEROMOTOCO|HEROMOTOCO25FEB25MARFUT|FUTSTK|HEROMOTOCO-FUTSTK|2100109953474|100.6|-100.6|6001|0.05|150|1|-1||2025-02-27T14:30:00|HEROMOTOCO 27FEB27MAR SPD|1|1|HEROMOTOCO25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9883625|4|DLF|DLF25FEB25MARFUT|FUTSTK|DLF-FUTSTK|2100109883625|17.1|-17.1|33001|0.05|825|1|-1||2025-02-27T14:30:00|DLF 27FEB27MAR SPD|1|1|DLF25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10726909|4|JSWSTEEL|JSWSTEEL25MAR25APRFUT|FUTSTK|JSWSTEEL-FUTSTK|2100110726909|24.1|-24.1|27001|0.05|675|1|-1||2025-03-27T14:30:00|JSWSTEEL 27MAR24APR SPD|1|1|JSWSTEEL25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10665605|4|TIINDIA|TIINDIA25FEB25MARFUT|FUTSTK|TIINDIA-FUTSTK|2100110665605|67.35|-67.35|7501|0.05|150|1|-1||2025-02-27T14:30:00|TIINDIA 27FEB27MAR SPD|1|1|TIINDIA25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10025250|4|IRCTC|IRCTC25FEB25MARFUT|FUTSTK|IRCTC-FUTSTK|2100110025250|18.95|-18.95|26251|0.05|875|1|-1||2025-02-27T14:30:00|IRCTC 27FEB27MAR SPD|1|1|IRCTC25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9110557|4|BHARATFORG|BHARATFORG25FEB25MARFUT|FUTSTK|BHARATFORG-FUTSTK|2100109110557|27.5|-27.5|20001|0.05|500|1|-1||2025-02-27T14:30:00|BHARATFORG 27FEB27MAR SPD|1|1|BHARATFORG25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9033100|4|APOLLOTYRE|APOLLOTYRE25FEB25MARFUT|FUTSTK|APOLLOTYRE-FUTSTK|2100109033100|10.35|-10.35|51001|0.05|1700|1|-1||2025-02-27T14:30:00|APOLLOTYRE 27FEB27MAR SPD|1|1|APOLLOTYRE25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10412755|4|IGL|IGL25MAR25APRFUT|FUTSTK|IGL-FUTSTK|2100110412755|4.61|-4.61|110001|0.01|2750|1|-1||2025-03-27T14:30:00|IGL 27MAR24APR SPD|1|1|IGL25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|11145767|4|OBEROIRLTY|OBEROIRLTY25MAR25APRFUT|FUTSTK|OBEROIRLTY-FUTSTK|2100111145767|40.15|-40.15|10501|0.05|350|1|-1||2025-03-27T14:30:00|OBEROIRLTY 27MAR24APR SPD|1|1|OBEROIRLTY25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9129404|4|FINNIFTY|FINNIFTY25FEB25MARFUT|FUTIDX|FINNIFTY-FUTIDX|2100109129404|466.1|-466.1|1801|0.05|65|1|-1||2025-02-27T14:30:00|FINNIFTY 27FEB27MAR SPD|1|1|FINNIFTY25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9242456|4|DLF|DLF25MAR25APRFUT|FUTSTK|DLF-FUTSTK|2100109242456|17.2|-17.2|33001|0.05|825|1|-1||2025-03-27T14:30:00|DLF 27MAR24APR SPD|1|1|DLF25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10205132|4|NCC|NCC25FEB25MARFUT|FUTSTK|NCC-FUTSTK|2100110205132|2.05|-7.95|88751|0.05|1775|1|-1||2025-02-27T14:30:00|NCC 27FEB27MAR SPD|1|1|NCC25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|11139875|4|NHPC|NHPC25MAR25APRFUT|FUTSTK|NHPC-FUTSTK|2100111139875|1.81|-1.81|256001|0.01|6400|1|-1||2025-03-27T14:30:00|NHPC 27MAR24APR SPD|1|1|NHPC25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9062195|4|ADANIPORTS|ADANIPORTS25MAR25APRFUT|FUTSTK|ADANIPORTS-FUTSTK|2100109062195|28.5|-28.5|20001|0.05|400|1|-1||2025-03-27T14:30:00|ADANIPORTS 27MAR24APR SPD|1|1|ADANIPORTS25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10612811|4|RBLBANK|RBLBANK25FEB25MARFUT|FUTSTK|RBLBANK-FUTSTK|2100110612811|4.02|-4.02|150001|0.01|2500|1|-1||2025-02-27T14:30:00|RBLBANK 27FEB27MAR SPD|1|1|RBLBANK25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|11184289|4|TORNTPHARM|TORNTPHARM25MAR25APRFUT|FUTSTK|TORNTPHARM-FUTSTK|2100111184289|77.05|-77.05|7501|0.05|250|1|-1||2025-03-27T14:30:00|TORNTPHARM 27MAR24APR SPD|1|1|TORNTPHARM25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10507554|4|PIDILITIND|PIDILITIND25FEB25MARFUT|FUTSTK|PIDILITIND-FUTSTK|2100110507554|71|-71|7501|0.05|250|1|-1||2025-02-27T14:30:00|PIDILITIND 27FEB27MAR SPD|1|1|PIDILITIND25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|18929593|4|TORNTPOWER|TORNTPOWER25MAR25APRFUT|FUTSTK|TORNTPOWER-FUTSTK|2100118929593|32|-32|15001|0.05|375|1|-1||2025-03-27T14:30:00|TORNTPOWER 27MAR24APR SPD|1|1|TORNTPOWER25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10643835|4|TATACONSUM|TATACONSUM25FEB25MARFUT|FUTSTK|TATACONSUM-FUTSTK|2100110643835|25.85|-25.85|22801|0.05|456|1|-1||2025-02-27T14:30:00|TATACONSUM 27FEB27MAR SPD|1|1|TATACONSUM25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|11140132|4|NMDC|NMDC25MAR25APRFUT|FUTSTK|NMDC-FUTSTK|2100111140132|1.58|-1.58|405001|0.01|13500|1|-1||2025-03-27T14:30:00|NMDC 27MAR24APR SPD|1|1|NMDC25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9013748|4|ADANIGREEN|ADANIGREEN25FEB25MARFUT|FUTSTK|ADANIGREEN-FUTSTK|2100109013748|12.1|-33.75|18751|0.05|375|1|-1||2025-02-27T14:30:00|ADANIGREEN 27FEB27MAR SPD|1|1|ADANIGREEN25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10407173|4|PEL|PEL25FEB25MARFUT|FUTSTK|PEL-FUTSTK|2100110407173|24.55|-24.55|22501|0.05|750|1|-1||2025-02-27T14:30:00|PEL 27FEB27MAR SPD|1|1|PEL25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10418393|4|INDUSTOWER|INDUSTOWER25MAR25APRFUT|FUTSTK|INDUSTOWER-FUTSTK|2100110418393|8.8|-8.8|68001|0.05|1700|1|-1||2025-03-27T14:30:00|INDUSTOWER 27MAR24APR SPD|1|1|INDUSTOWER25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|11131674|4|MRF|MRF25MAR25APRFUT|FUTSTK|MRF-FUTSTK|2100111131674|2755.25|-2755.25|201|0.05|5|1|-1||2025-03-27T14:30:00|MRF 27MAR24APR SPD|1|1|MRF25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10621800|4|SRF|SRF25FEB25MARFUT|FUTSTK|SRF-FUTSTK|2100110621800|70.8|-70.8|11251|0.05|375|1|-1||2025-02-27T14:30:00|SRF 27FEB27MAR SPD|1|1|SRF25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10288538|4|HINDUNILVR|HINDUNILVR25MAR25APRFUT|FUTSTK|HINDUNILVR-FUTSTK|2100110288538|58.8|-58.8|9001|0.05|300|1|-1||2025-03-27T14:30:00|HINDUNILVR 27MAR24APR SPD|1|1|HINDUNILVR25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9136687|4|BSOFT|BSOFT25MAR25APRFUT|FUTSTK|BSOFT-FUTSTK|2100109136687|12.7|-12.7|40001|0.05|1000|1|-1||2025-03-27T14:30:00|BSOFT 27MAR24APR SPD|1|1|BSOFT25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10073184|4|LAURUSLABS|LAURUSLABS25FEB25MARFUT|FUTSTK|LAURUSLABS-FUTSTK|2100110073184|15.1|-15.1|51001|0.05|1700|1|-1||2025-02-27T14:30:00|LAURUSLABS 27FEB27MAR SPD|1|1|LAURUSLABS25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9070745|4|AUBANK|AUBANK25FEB25MARFUT|FUTSTK|AUBANK-FUTSTK|2100109070745|5.2|-22.65|40001|0.05|1000|1|-1||2025-02-27T14:30:00|AUBANK 27FEB27MAR SPD|1|1|AUBANK25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9237317|4|DALBHARAT|DALBHARAT25MAR25APRFUT|FUTSTK|DALBHARAT-FUTSTK|2100109237317|45|-45|13751|0.05|275|1|-1||2025-03-27T14:30:00|DALBHARAT 27MAR24APR SPD|1|1|DALBHARAT25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10616144|4|SAIL|SAIL25FEB25MARFUT|FUTSTK|SAIL-FUTSTK|2100110616144|2.65|-2.65|200001|0.01|4000|1|-1||2025-02-27T14:30:00|SAIL 27FEB27MAR SPD|1|1|SAIL25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9974239|4|HINDUNILVR|HINDUNILVR25FEB25MARFUT|FUTSTK|HINDUNILVR-FUTSTK|2100109974239|58.5|-58.5|9001|0.05|300|1|-1||2025-02-27T14:30:00|HINDUNILVR 27FEB27MAR SPD|1|1|HINDUNILVR25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|11185093|4|TRENT|TRENT25MAR25APRFUT|FUTSTK|TRENT-FUTSTK|2100111185093|132.05|-132.05|4001|0.05|100|1|-1||2025-03-27T14:30:00|TRENT 27MAR24APR SPD|1|1|TRENT25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10674586|4|UPL|UPL25FEB25MARFUT|FUTSTK|UPL-FUTSTK|2100110674586|15.55|-15.55|40651|0.05|1355|1|-1||2025-02-27T14:30:00|UPL 27FEB27MAR SPD|1|1|UPL25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|18890015|4|NBCC|NBCC25FEB25MARFUT|FUTSTK|NBCC-FUTSTK|2100118890015|2.14|-2.14|232001|0.01|5800|1|-1||2025-02-27T14:30:00|NBCC 27FEB27MAR SPD|1|1|NBCC25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10035013|4|ITC|ITC25FEB25MARFUT|FUTSTK|ITC-FUTSTK|2100110035013|10.3|-10.3|48001|0.05|1600|1|-1||2025-02-27T14:30:00|ITC 27FEB27MAR SPD|1|1|ITC25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9086169|4|ATGL|ATGL25MAR25APRFUT|FUTSTK|ATGL-FUTSTK|2100109086169|14.25|-14.25|31001|0.05|775|1|-1||2025-03-27T14:30:00|ATGL 27MAR24APR SPD|1|1|ATGL25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9388638|4|EXIDEIND|EXIDEIND25MAR25APRFUT|FUTSTK|EXIDEIND-FUTSTK|2100109388638|9.25|-9.25|54001|0.05|1800|1|-1||2025-03-27T14:30:00|EXIDEIND 27MAR24APR SPD|1|1|EXIDEIND25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10727168|4|JUBLFOOD|JUBLFOOD25MAR25APRFUT|FUTSTK|JUBLFOOD-FUTSTK|2100110727168|16.1|-16.1|37501|0.05|1250|1|-1||2025-03-27T14:30:00|JUBLFOOD 27MAR24APR SPD|1|1|JUBLFOOD25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10622057|4|SUNPHARMA|SUNPHARMA25FEB25MARFUT|FUTSTK|SUNPHARMA-FUTSTK|2100110622057|42.5|-42.5|14001|0.05|350|1|-1||2025-02-27T14:30:00|SUNPHARMA 27FEB27MAR SPD|1|1|SUNPHARMA25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|11137201|4|MIDCPNIFTY|MIDCPNIFTY25FEB25APRFUT|FUTIDX|MIDCPNIFTY-FUTIDX|2100111137201|228.45|-228.45|2801|0.05|120|1|-1||2025-02-27T14:30:00|MIDCPNIFTY 27FEB24APR SPD|1|1|MIDCPNIFTY25FEB25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10411958|4|IDFCFIRSTB|IDFCFIRSTB25MAR25APRFUT|FUTSTK|IDFCFIRSTB-FUTSTK|2100110411958|1.56|-1.56|375001|0.01|7500|1|-1||2025-03-27T14:30:00|IDFCFIRSTB 27MAR24APR SPD|1|1|IDFCFIRSTB25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10151574|4|HINDCOPPER|HINDCOPPER25MAR25APRFUT|FUTSTK|HINDCOPPER-FUTSTK|2100110151574|5.66|-5.66|106001|0.01|2650|1|-1||2025-03-27T14:30:00|HINDCOPPER 27MAR24APR SPD|1|1|HINDCOPPER25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|11184032|4|TITAN|TITAN25MAR25APRFUT|FUTSTK|TITAN-FUTSTK|2100111184032|82.15|-82.15|7001|0.05|175|1|-1||2025-03-27T14:30:00|TITAN 27MAR24APR SPD|1|1|TITAN25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9014449|4|MIDCPNIFTY|MIDCPNIFTY25MAR25APRFUT|FUTIDX|MIDCPNIFTY-FUTIDX|2100109014449|229.3|-229.3|2801|0.05|120|1|-1||2025-03-27T14:30:00|MIDCPNIFTY 27MAR24APR SPD|1|1|MIDCPNIFTY25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9635441|4|GODREJPROP|GODREJPROP25MAR25APRFUT|FUTSTK|GODREJPROP-FUTSTK|2100109635441|48.75|-48.75|9001|0.05|225|1|-1||2025-03-27T14:30:00|GODREJPROP 27MAR24APR SPD|1|1|GODREJPROP25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9014966|4|AARTIIND|AARTIIND25MAR25APRFUT|FUTSTK|AARTIIND-FUTSTK|2100109014966|11.15|-11.15|50001|0.05|1000|1|-1||2025-03-27T14:30:00|AARTIIND 27MAR24APR SPD|1|1|AARTIIND25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9635780|4|CIPLA|CIPLA25FEB25MARFUT|FUTSTK|CIPLA-FUTSTK|2100109635780|36.3|-36.3|16251|0.05|325|1|-1||2025-02-27T14:30:00|CIPLA 27FEB27MAR SPD|1|1|CIPLA25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9016504|4|ABCAPITAL|ABCAPITAL25MAR25APRFUT|FUTSTK|ABCAPITAL-FUTSTK|2100109016504|3.99|-3.99|135001|0.01|2700|1|-1||2025-03-27T14:30:00|ABCAPITAL 27MAR24APR SPD|1|1|ABCAPITAL25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|11166014|4|RAMCOCEM|RAMCOCEM25MAR25APRFUT|FUTSTK|RAMCOCEM-FUTSTK|2100111166014|21.85|-21.85|25501|0.05|850|1|-1||2025-03-27T14:30:00|RAMCOCEM 27MAR24APR SPD|1|1|RAMCOCEM25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9106460|4|BERGEPAINT|BERGEPAINT25FEB25MARFUT|FUTSTK|BERGEPAINT-FUTSTK|2100109106460|12.15|-12.15|52801|0.05|1320|1|-1||2025-02-27T14:30:00|BERGEPAINT 27FEB27MAR SPD|1|1|BERGEPAINT25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10145916|4|HCLTECH|HCLTECH25MAR25APRFUT|FUTSTK|HCLTECH-FUTSTK|2100110145916|43.25|-43.25|14001|0.05|350|1|-1||2025-03-27T14:30:00|HCLTECH 27MAR24APR SPD|1|1|HCLTECH25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|18890272|4|NBCC|NBCC25MAR25APRFUT|FUTSTK|NBCC-FUTSTK|2100118890272|2.14|-2.14|232001|0.01|5800|1|-1||2025-03-27T14:30:00|NBCC 27MAR24APR SPD|1|1|NBCC25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10652541|4|TATAMOTORS|TATAMOTORS25FEB25MARFUT|FUTSTK|TATAMOTORS-FUTSTK|2100110652541|17.15|-17.15|27501|0.05|550|1|-1||2025-02-27T14:30:00|TATAMOTORS 27FEB27MAR SPD|1|1|TATAMOTORS25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10081712|4|MGL|MGL25FEB25MARFUT|FUTSTK|MGL-FUTSTK|2100110081712|32.65|-32.65|20001|0.05|400|1|-1||2025-02-27T14:30:00|MGL 27FEB27MAR SPD|1|1|MGL25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|11175781|4|SRF|SRF25MAR25APRFUT|FUTSTK|SRF-FUTSTK|2100111175781|71.05|-71.05|11251|0.05|375|1|-1||2025-03-27T14:30:00|SRF 27MAR24APR SPD|1|1|SRF25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|11112717|4|LTIM|LTIM25MAR25APRFUT|FUTSTK|LTIM-FUTSTK|2100111112717|143.1|-143.1|4501|0.05|150|1|-1||2025-03-27T14:30:00|LTIM 27MAR24APR SPD|1|1|LTIM25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|11169088|4|RECLTD|RECLTD25MAR25APRFUT|FUTSTK|RECLTD-FUTSTK|2100111169088|10.2|-10.2|50001|0.05|1000|1|-1||2025-03-27T14:30:00|RECLTD 27MAR24APR SPD|1|1|RECLTD25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10437621|4|IRFC|IRFC25MAR25APRFUT|FUTSTK|IRFC-FUTSTK|2100110437621|2.91|-2.91|141001|0.01|3525|1|-1||2025-03-27T14:30:00|IRFC 27MAR24APR SPD|1|1|IRFC25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10436573|4|IRB|IRB25MAR25APRFUT|FUTSTK|IRB-FUTSTK|2100110436573|1.25|-1.25|410001|0.01|10250|1|-1||2025-03-27T14:30:00|IRB 27MAR24APR SPD|1|1|IRB25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9388895|4|FEDERALBNK|FEDERALBNK25MAR25APRFUT|FUTSTK|FEDERALBNK-FUTSTK|2100109388895|4.62|-4.62|150001|0.01|5000|1|-1||2025-03-27T14:30:00|FEDERALBNK 27MAR24APR SPD|1|1|FEDERALBNK25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10682542|4|WIPRO|WIPRO25FEB25MARFUT|FUTSTK|WIPRO-FUTSTK|2100110682542|7.8|-7.8|90001|0.05|3000|1|-1||2025-02-27T14:30:00|WIPRO 27FEB27MAR SPD|1|1|WIPRO25FEB25MARFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|10716410|4|JIOFIN|JIOFIN25MAR25APRFUT|FUTSTK|JIOFIN-FUTSTK|2100110716410|5.74|-5.74|82501|0.01|1650|1|-1||2025-03-27T14:30:00|JIOFIN 27MAR24APR SPD|1|1|JIOFIN25MAR25APRFUT
# Warning: Expected at least 23 fields, but got 21 in record: NSEFO|9079827|4|APOLLOTYRE|APOLLOTYRE25MAR25APRFUT|FUTSTK|APOLLOTYRE-FUTSTK|2100109079827|10.25|-10.25|51001|0.05|1700|1|-1||2025-03-27T14:30:00|APOLLOTYRE 27MAR24APR SPD|1|1|APOLLOTYRE25MAR25APRFUT
# CSV file 'data.csv' created successfully.

# %%
df["ExpiryDate"].unique()
# Out:
# array(['2025-03-27 14:30:00', '2025-04-24 14:30:00',
#        '2025-02-27 14:30:00'], dtype=object)

# %%
import re

def extract_futures(symbol, df):
    """
    Extracts future contract details from the given symbol.

    Args:
    symbol (str): The future contract description.
    df (DataFrame): The DataFrame containing futures contract data.

    Returns:
    tuple: (ExchangeInstrumentID of first expiry, second expiry contract description)
    """
    # Regular expression to match stock symbol and expiry months
    pattern = re.match(r"([A-Z\&\-]+)(\d{2}[A-Z]+)(\d{2}[A-Z]+)FUT", symbol)
    
    if pattern:
        stock_symbol = pattern.group(1)  # Extract stock symbol (e.g., TITAN)
        expiry1 = pattern.group(2)       # First expiry (e.g., 25MAR)
        expiry2 = pattern.group(3)       # Second expiry (e.g., 25APR)

        # Check if the first future contract exists in the DataFrame
        fut1_df = df[df['Description'] == f"{stock_symbol}{expiry1}FUT"]

        if not fut1_df.empty:
            fut1_exchange_id = fut1_df['ExchangeInstrumentID'].values[0]  # Extract ExchangeInstrumentID safely
        else:
            fut1_exchange_id = None  # Handle missing case

        fut2 = f"{stock_symbol}{expiry2}FUT"

        return fut1_exchange_id, fut2
    else:
        return None

# Iterate over descriptions ending with "SPD"
for i in df[df["Strike"].str.endswith("SPD")]['Description']:
    result = extract_futures(i, df)

    if result:
        print("Extracted Futures:")
        print(result[0] if result[0] is not None else "ExchangeInstrumentID not found")  # TITAN25MARFUT ExchangeInstrumentID or None
        print(result[1])  # TITAN25APRFUT
    else:
        print(f"No match found for {i}")
# Out:
# Extracted Futures:
# 41463
# TECHM25MARFUT
# Extracted Futures:
# 43400
# TITAN25APRFUT
# Extracted Futures:
# 41029
# ITC25APRFUT
# Extracted Futures:
# 35057
# ADANIENT25APRFUT
# Extracted Futures:
# 43438
# WIPRO25APRFUT
# Extracted Futures:
# 41559
# WIPRO25MARFUT
# Extracted Futures:
# 43396
# TECHM25APRFUT
# Extracted Futures:
# 35033
# ADANIENT25MARFUT
# Extracted Futures:
# 41513
# ULTRACEMCO25MARFUT
# Extracted Futures:
# 39122
# JSWSTEEL25MARFUT
# Extracted Futures:
# 35215
# ASIANPAINT25APRFUT
# Extracted Futures:
# 39039
# ITC25MARFUT
# Extracted Futures:
# 35245
# AXISBANK25APRFUT
# Extracted Futures:
# 41615
# JSWSTEEL25APRFUT
# Extracted Futures:
# 35310
# AXISBANK25MARFUT
# Extracted Futures:
# 43406
# ULTRACEMCO25APRFUT
# Extracted Futures:
# 35154
# ASIANPAINT25MARFUT
# Extracted Futures:
# 41498
# TITAN25MARFUT

# %%
import re
import json

def extract_futures(symbol, df):
    """
    Extracts future contract details from the given symbol.

    Args:
    symbol (str): The future contract description.
    df (DataFrame): The DataFrame containing futures contract data.

    Returns:
    tuple: (ExchangeInstrumentID of first expiry, ExchangeInstrumentID of second expiry)
    """
    # Regular expression to match stock symbol and expiry months
    pattern = re.match(r"([A-Z\&\-]+)(\d{2}[A-Z]+)(\d{2}[A-Z]+)FUT", symbol)
    
    if pattern:
        stock_symbol = pattern.group(1)  # Extract stock symbol (e.g., TITAN)
        expiry1 = pattern.group(2)       # First expiry (e.g., 25MAR)
        expiry2 = pattern.group(3)       # Second expiry (e.g., 25APR)

        # Fetch F1 ExchangeInstrumentID
        fut1_df = df[df['Description'] == f"{stock_symbol}{expiry1}FUT"]
        fut1_exchange_id = int(fut1_df['ExchangeInstrumentID'].values[0]) if not fut1_df.empty else None

        # Fetch F2 ExchangeInstrumentID
        fut2_df = df[df['Description'] == f"{stock_symbol}{expiry2}FUT"]
        fut2_exchange_id = int(fut2_df['ExchangeInstrumentID'].values[0]) if not fut2_df.empty else None

        return fut1_exchange_id, fut2_exchange_id
    else:
        return None, None

# Dictionary to store results
futures_mapping = {}

# Iterate over descriptions ending with "SPD"
for _, row in df[df["Strike"].str.endswith("SPD")].iterrows():
    parent_exchange_id = int(row['ExchangeInstrumentID'])  # Get parent ExchangeInstrumentID
    result = extract_futures(row['Description'], df)

    if result:
        f1_exchange_id = result[0]
        f2_exchange_id = result[1]
        
        # Store only if both F1 and F2 are found
        if f1_exchange_id and f2_exchange_id:
            futures_mapping[parent_exchange_id] = [f1_exchange_id, f2_exchange_id]

# Save to JSON file
output_file = r"D:\YASH\Cleaning\Data\Futuresdataforwardfil\futures_mapping.json"
with open(output_file, "w") as json_file:
    json.dump(futures_mapping, json_file, indent=4)

print(f"Futures mapping saved at: {output_file}")
# Out:
# Futures mapping saved at: D:\YASH\Cleaning\Data\Futuresdataforwardfil\futures_mapping.json

# %%
import re
import json

def extract_futures(symbol, df):
    """
    Extracts future contract details from the given symbol.

    Args:
    symbol (str): The future contract description.
    df (DataFrame): The DataFrame containing futures contract data.

    Returns:
    tuple: (ExchangeInstrumentID of first expiry, ExchangeInstrumentID of second expiry)
    """
    # Regular expression to match stock symbol and expiry months
    pattern = re.match(r"([A-Z\&\-]+)(\d{2}[A-Z]+)(\d{2}[A-Z]+)FUT", symbol)
    
    if pattern:
        stock_symbol = pattern.group(1)  # Extract stock symbol (e.g., TITAN)
        expiry1 = pattern.group(2)       # First expiry (e.g., 25MAR)
        expiry2 = pattern.group(3)       # Second expiry (e.g., 25APR)

        # Fetch F1 ExchangeInstrumentID
        fut1_df = df[df['Description'] == f"{stock_symbol}{expiry1}FUT"]
        fut1_exchange_id = int(fut1_df['ExchangeInstrumentID'].values[0]) if not fut1_df.empty else None

        # Fetch F2 ExchangeInstrumentID
        fut2_df = df[df['Description'] == f"{stock_symbol}{expiry2}FUT"]
        fut2_exchange_id = int(fut2_df['ExchangeInstrumentID'].values[0]) if not fut2_df.empty else None

        return fut1_exchange_id, fut2_exchange_id
    else:
        return None, None

# Dictionary to store parent-child mapping
futures_mapping = {}

# List to store ExchangeInstrumentIDs
exchange_instrument_list = []

# Iterate over descriptions ending with "SPD"
for _, row in df[df["Strike"].str.endswith("SPD")].iterrows():
    parent_exchange_id = int(row['ExchangeInstrumentID'])  # Convert to int
    result = extract_futures(row['Description'], df)

    if result:
        f1_exchange_id = result[0]
        f2_exchange_id = result[1]

        # Store only if both F1 and F2 are found
        if f1_exchange_id and f2_exchange_id:
            futures_mapping[parent_exchange_id] = [f1_exchange_id, f2_exchange_id]

            # Add all IDs to the list
            exchange_instrument_list.append({"exchangeSegment": 2, "exchangeInstrumentID": f1_exchange_id})
            exchange_instrument_list.append({"exchangeSegment": 2, "exchangeInstrumentID": f2_exchange_id})

    # Add parent exchangeInstrumentID to the list as well
    exchange_instrument_list.append({"exchangeSegment": 2, "exchangeInstrumentID": parent_exchange_id})

# Remove duplicates from the list
exchange_instrument_list = list({v["exchangeInstrumentID"]: v for v in exchange_instrument_list}.values())

# Save Futures Mapping to JSON
futures_mapping_file = r"D:\YASH\Cleaning\Data\Futuresdataforwardfil\futures_mapping.json"
with open(futures_mapping_file, "w") as json_file:
    json.dump(futures_mapping, json_file, indent=4)

# Save ExchangeInstrumentID List to JSON
exchange_instrument_file = r"D:\YASH\Cleaning\Data\Futuresdataforwardfil\exchange_instruments.json"
with open(exchange_instrument_file, "w") as json_file:
    json.dump(exchange_instrument_list, json_file, indent=4)

print(f"✅ Futures mapping saved at: {futures_mapping_file}")
print(f"✅ Exchange Instrument List saved at: {exchange_instrument_file}")
# Out:
# ✅ Futures mapping saved at: D:\YASH\Cleaning\Data\Futuresdataforwardfil\futures_mapping.json
# ✅ Exchange Instrument List saved at: D:\YASH\Cleaning\Data\Futuresdataforwardfil\exchange_instruments.json

# %%
df[df["Name"]=="TITAN"]
# Out:
#     Unnamed: 0 ExchangeSegment  ExchangeInstrumentID   Name  \
# 2            2           NSEFO                 73632  TITAN
# 5            5           NSEFO                 43400  TITAN
# 24          24           NSEFO                 41498  TITAN
# 28          28           NSEFO              11184032  TITAN
# 44          44           NSEFO              10666888  TITAN
#
#            Description  Series NameWithSeries   InstrumentID  PriceBand.High  \
# 2        TITAN25APRFUT  FUTSTK   TITAN-FUTSTK  2511400073632         3907.00
# 5        TITAN25MARFUT  FUTSTK   TITAN-FUTSTK  2508600043400         3881.35
# 24       TITAN25FEBFUT  FUTSTK   TITAN-FUTSTK  2505800041498         3858.80
# 28  TITAN25MAR25APRFUT  FUTSTK   TITAN-FUTSTK  2100111184032           88.25
# 44  TITAN25FEB25MARFUT  FUTSTK   TITAN-FUTSTK  2100110666888           87.70
#
#     PriceBand.Low  FreezeQty  TickSize  LotSize  Multiplier displayName  \
# 2         3196.65       7001      0.05      175           1       TITAN
# 5         3175.65       7001      0.05      175           1       TITAN
# 24        3157.20       7001      0.05      175           1       TITAN
# 28         -88.25       7001      0.05      175           1         NaN
# 44         -87.70       7001      0.05      175           1         NaN
#
#              ExpiryDate                Strike  OptionType  TickerName
# 2   2025-04-24 14:30:00       TITAN 24APR2025           1           1
# 5   2025-03-27 14:30:00       TITAN 27MAR2025           1           1
# 24  2025-02-27 14:30:00       TITAN 27FEB2025           1           1
# 28  2025-03-27 14:30:00  TITAN 27MAR24APR SPD           1           1
# 44  2025-02-27 14:30:00  TITAN 27FEB27MAR SPD           1           1

# %%
#create a dic of ExchangeInstrumentID and  Description

df1=df[["ExchangeInstrumentID","Description"]]
df1=df1.drop_duplicates()
df1=df1.set_index("ExchangeInstrumentID")
df1=df1.to_dict()
#save to json
import json
with open('ExchangeInstrumentID.json', 'w') as fp:
    json.dump(df1, fp)

# %%
import re

def extract_symbols(text):


    matches = re.findall(r'^([A-Z]+)\s\d{2}([A-Z]+)\d{2}([A-Z]+)\sSPD$', text)
    
    if matches:

        stock_name, month1, month2 = matches[0]
        symbol1 = f"{stock_name}{month1}"
        symbol2 = f"{stock_name}{month2}"
        return symbol1, symbol2
    else:
        return None
spdsym=df[df["displayName"].isna()]["Description"].apply(extract_symbols)
print(spdsym)
result = extract_symbols(spdsym)

if result:
    print("Symbol 1:", result[0])  # Output: TITANJAN
    print("Symbol 2:", result[1])  # Output: TITANFEB
else:
    print("No valid symbols found")
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# Name: Description, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 18
#      16 spdsym=df[df["displayName"].isna()]["Description"].apply(extract_symbols)
#      17 print(spdsym)
# ---> 18 result = extract_symbols(spdsym)
#      20 if result:
#      21     print("Symbol 1:", result[0])  # Output: TITANJAN
#
# Cell In[17], line 6, in extract_symbols(text)
#       3 def extract_symbols(text):
# ----> 6     matches = re.findall(r'^([A-Z]+)\s\d{2}([A-Z]+)\d{2}([A-Z]+)\sSPD$', text)
#       8     if matches:
#      10         stock_name, month1, month2 = matches[0]
#
# File C:\Program Files\Python312\Lib\re\__init__.py:217, in findall(pattern, string, flags)
#     209 def findall(pattern, string, flags=0):
#     210     """Return a list of all non-overlapping matches in the string.
#     211
#     212     If one or more capturing groups are present in the pattern, return
#    (...)
#     215
#     216     Empty matches are included in the result."""
# --> 217     return _compile(pattern, flags).findall(string)
#
# TypeError: expected string or bytes-like object, got 'Series'

# %%
df["displayName"].unique()
# Out:
# array([nan, 'TITAN', 'JSWSTEEL', 'TECHM', 'WIPRO', 'ADANIENT',
#        'ULTRACEMCO', 'ITC', 'ASIANPAINT', 'AXISBANK'], dtype=object)

# %%
asp=df[df["Name"]=="JSWSTEEL"]
asp
# Out:
#     Unnamed: 0 ExchangeSegment  ExchangeInstrumentID      Name  \
# 9            9           NSEFO              10056847  JSWSTEEL
# 17          17           NSEFO              10559186  JSWSTEEL
# 19          19           NSEFO                 41615  JSWSTEEL
# 40          40           NSEFO                 39122  JSWSTEEL
# 43          43           NSEFO                 41094  JSWSTEEL
#
#               Description  Series   NameWithSeries   InstrumentID  \
# 9   JSWSTEEL25FEB25MARFUT  FUTSTK  JSWSTEEL-FUTSTK  2100110056847
# 17  JSWSTEEL25JAN25FEBFUT  FUTSTK  JSWSTEEL-FUTSTK  2100110559186
# 19       JSWSTEEL25MARFUT  FUTSTK  JSWSTEEL-FUTSTK  2508600041615
# 40       JSWSTEEL25FEBFUT  FUTSTK  JSWSTEEL-FUTSTK  2505800039122
# 43       JSWSTEEL25JANFUT  FUTSTK  JSWSTEEL-FUTSTK  2503000041094
#
#     PriceBand.High  PriceBand.Low  FreezeQty  TickSize  LotSize  Multiplier  \
# 9            22.65         -22.65      27001      0.05      675           1
# 17           22.55         -22.55      27001      0.05      675           1
# 19         1003.30         820.85      27001      0.05      675           1
# 40          997.00         815.75      27001      0.05      675           1
# 43          990.95         810.80      27001      0.05      675           1
#
#    displayName           ExpiryDate                   Strike  OptionType  \
# 9          NaN  2025-02-27 14:30:00  JSWSTEEL 27FEB27MAR SPD           1
# 17         NaN  2025-01-30 14:30:00  JSWSTEEL 30JAN27FEB SPD           1
# 19    JSWSTEEL  2025-03-27 14:30:00       JSWSTEEL 27MAR2025           1
# 40    JSWSTEEL  2025-02-27 14:30:00       JSWSTEEL 27FEB2025           1
# 43    JSWSTEEL  2025-01-30 14:30:00       JSWSTEEL 30JAN2025           1
#
#     TickerName
# 9            1
# 17           1
# 19           1
# 40           1
# 43           1

# %%
{10559186:[41094,39122]}

# %%
df["InstrumentID"].unique()
df["Name"].unique()


instrument_list = []

df = df.drop_duplicates(subset=['InstrumentID'])
asp = asp.reset_index(drop=True)
for i in range(len(asp["InstrumentID"])):

    instrument_list.append({"exchangeSegment":2,"exchangeInstrumentID":int(asp["ExchangeInstrumentID"][i])})
#save into json file
import json
with open('Titaninstrument_list.json', 'w') as f:
    json.dump(instrument_list, f)

# %%
df["InstrumentID"].unique()
df["Name"].unique()


instrument_list = []

df = df.drop_duplicates(subset=['InstrumentID'])
asp = asp.reset_index(drop=True)


#sort asp by expiry date
asp=asp.sort_values(by="ExpiryDate")

for i in range(len(asp["InstrumentID"])):

    instrument_list.append({"exchangeSegment":2,"exchangeInstrumentID":int(asp["ExchangeInstrumentID"][i])})
#save into json file
import json
with open('Titaninstrument_list.json', 'w') as f:
    json.dump(instrument_list, f)

# %%
asp.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 asp.columns
#
# NameError: name 'asp' is not defined

# %%
import pandas as pd

df5=pd.read_csv('formateddata.csv')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17636\3415216963.py:3: DtypeWarning: Columns (17,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df5=pd.read_csv('formateddata.csv')

# %%
df5["instrument_category"].unique()
# Out:
# array([2, 1, 4])

# %%
df5
# Out:
#       exchange     token  instrument_category  underlying  \
# 0        NSEFO    101335                    2      CONCOR
# 1        NSEFO     75867                    2   BANKNIFTY
# 2        NSEFO    102204                    2   DELHIVERY
# 3        NSEFO     78442                    2      AUBANK
# 4        NSEFO    134839                    2        NHPC
# ...        ...       ...                  ...         ...
# 86507    NSEFO  10436573                    4         IRB
# 86508    NSEFO   9388895                    4  FEDERALBNK
# 86509    NSEFO  10682542                    4       WIPRO
# 86510    NSEFO  10716410                    4      JIOFIN
# 86511    NSEFO   9079827                    4  APOLLOTYRE
#
#                contract_symbol instrument_type            product  \
# 0             CONCOR25APR780PE          OPTSTK      CONCOR-OPTSTK
# 1        BANKNIFTY25APR66000CE          OPTIDX   BANKNIFTY-OPTIDX
# 2          DELHIVERY25FEB245CE          OPTSTK   DELHIVERY-OPTSTK
# 3             AUBANK25MAR530CE          OPTSTK      AUBANK-OPTSTK
# 4                NHPC25MAR60CE          OPTSTK        NHPC-OPTSTK
# ...                        ...             ...                ...
# 86507         IRB25MAR25APRFUT          FUTSTK         IRB-FUTSTK
# 86508  FEDERALBNK25MAR25APRFUT          FUTSTK  FEDERALBNK-FUTSTK
# 86509       WIPRO25FEB25MARFUT          FUTSTK       WIPRO-FUTSTK
# 86510      JIOFIN25MAR25APRFUT          FUTSTK      JIOFIN-FUTSTK
# 86511  APOLLOTYRE25MAR25APRFUT          FUTSTK  APOLLOTYRE-FUTSTK
#
#        contract_unique_id  price1  price2  ...  trading_status   alternate_id  \
# 0           2511400101335  123.90   63.30  ...               1  1100100004749
# 1           2511400075867   21.35    0.05  ...               1             -1
# 2           2505800102204   49.80    9.80  ...               1  1100100009599
# 3           2508600078442   61.40   17.50  ...               1  1100100021238
# 4           2508600134839   34.75    0.05  ...               1  1100100017400
# ...                   ...     ...     ...  ...             ...            ...
# 86507       2100110436573    1.25   -1.25  ...               1             -1
# 86508       2100109388895    4.62   -4.62  ...               1             -1
# 86509       2100110682542    7.80   -7.80  ...               1             -1
# 86510       2100110716410    5.74   -5.74  ...               1             -1
# 86511       2100109079827   10.25  -10.25  ...               1             -1
#
#        underlying_name               expiry                     strike  \
# 0               CONCOR  2025-04-24T14:30:00                      780.0
# 1           Nifty Bank  2025-04-24T14:30:00                    66000.0
# 2            DELHIVERY  2025-02-27T14:30:00                      245.0
# 3               AUBANK  2025-03-27T14:30:00                      530.0
# 4                 NHPC  2025-03-27T14:30:00                       60.0
# ...                ...                  ...                        ...
# 86507              NaN  2025-03-27T14:30:00         IRB 27MAR24APR SPD
# 86508              NaN  2025-03-27T14:30:00  FEDERALBNK 27MAR24APR SPD
# 86509              NaN  2025-02-27T14:30:00       WIPRO 27FEB27MAR SPD
# 86510              NaN  2025-03-27T14:30:00      JIOFIN 27MAR24APR SPD
# 86511              NaN  2025-03-27T14:30:00  APOLLOTYRE 27MAR24APR SPD
#
#       option_type            option_description                    flag1  \
# 0               4       CONCOR 24APR2025 PE 780                        1
# 1               3  BANKNIFTY 24APR2025 CE 66000                        1
# 2               3    DELHIVERY 27FEB2025 CE 245                        1
# 3               3       AUBANK 27MAR2025 CE 530                        1
# 4               3          NHPC 27MAR2025 CE 60                        1
# ...           ...                           ...                      ...
# 86507           1                             1         IRB25MAR25APRFUT
# 86508           1                             1  FEDERALBNK25MAR25APRFUT
# 86509           1                             1       WIPRO25FEB25MARFUT
# 86510           1                             1      JIOFIN25MAR25APRFUT
# 86511           1                             1  APOLLOTYRE25MAR25APRFUT
#
#        flag2          contract_code
# 0        1.0       CONCOR25APR780PE
# 1        1.0  BANKNIFTY25APR66000CE
# 2        1.0    DELHIVERY25FEB245CE
# 3        1.0       AUBANK25MAR530CE
# 4        1.0          NHPC25MAR60CE
# ...      ...                    ...
# 86507    NaN                    NaN
# 86508    NaN                    NaN
# 86509    NaN                    NaN
# 86510    NaN                    NaN
# 86511    NaN                    NaN
#
# [86512 rows x 23 columns]

# %%
df5[df5["instrument_category"]==1]["underlying_name"].unique()
# Remove rows where underlying_name is NaN
df5 = df5.dropna(subset=["underlying_name"])
# Remove rows where underlying_name ends with TEST
df5 = df5[~df5["underlying_name"].str.endswith("TEST")]

# %%
df5[df5["instrument_category"]==1]["underlying_name"].unique()
# Out:
# array(['ASIANPAINT', 'JIOFIN', 'SBIN', 'WIPRO', 'M&M', 'DRREDDY',
#        'CROMPTON', 'VBL', 'BAJAJ-AUTO', 'CIPLA', 'VEDL', 'PEL', 'IRB',
#        'SONACOMS', 'HEROMOTOCO', 'DIVISLAB', 'ATGL', 'INDUSINDBK',
#        'TATACHEM', 'TRENT', 'CYIENT', 'OFSS', 'MGL', 'LAURUSLABS',
#        'TATAELXSI', 'Nifty Bank', 'AUROPHARMA', 'RBLBANK', 'JSWENERGY',
#        'JINDALSTEL', 'BERGEPAINT', 'PHOENIXLTD', 'IDEA', 'TATAMOTORS',
#        'BHARATFORG', 'MAXHEALTH', 'IRCTC', 'CHAMBLFERT', 'SUNPHARMA',
#        'GODREJCP', 'ADANIENSOL', 'BALKRISIND', 'ASHOKLEY', 'IDFCFIRSTB',
#        'PERSISTENT', 'ICICIGI', 'ULTRACEMCO', 'APOLLOTYRE', 'GODREJPROP',
#        'BRITANNIA', 'BANDHANBNK', 'YESBANK', 'NATIONALUM', 'TATASTEEL',
#        'SHREECEM', 'DABUR', 'CHOLAFIN', 'ICICIPRULI', 'BANKINDIA',
#        'EICHERMOT', 'NMDC', 'ALKEM', 'AXISBANK', 'POLYCAB', 'ABFRL',
#        'DIXON', 'Nifty Fin Service', 'NCC', 'INDUSTOWER', 'ADANIGREEN',
#        'IPCALAB', 'SAIL', 'IOC', 'HINDALCO', 'NHPC', 'MANAPPURAM',
#        'POLICYBZR', 'GLENMARK', 'MCX', 'ASTRAL', 'TITAN', 'PAGEIND',
#        'BEL', 'BSOFT', 'BAJFINANCE', 'LICI', 'BHARTIARTL', 'FEDERALBNK',
#        'TORNTPHARM', 'COROMANDEL', 'COFORGE', 'ABB', 'LT', 'ANGELONE',
#        'APLAPOLLO', 'LTIM', 'NIFTY MID SELECT', 'MUTHOOTFIN', 'PETRONET',
#        'TCS', 'LUPIN', 'LICHSGFIN', 'UNITDSPR', 'HUDCO', 'CESC', 'COLPAL',
#        'INDHOTEL', 'Nifty 50', 'IRFC', 'HAVELLS', 'BIOCON', 'COALINDIA',
#        'JUBLFOOD', 'NAUKRI', 'PIDILITIND', 'DLF', 'KALYANKJIL',
#        'MOTHERSON', 'NESTLEIND', 'MFSL', 'HAL', 'LALPATHLAB', 'JKCEMENT',
#        'ABCAPITAL', 'BHEL', 'CUMMINSIND', 'CDSL', 'CUB', 'BATAINDIA',
#        'ZOMATO', 'TATACOMM', 'DALBHARAT', 'BOSCHLTD', 'TATACONSUM',
#        'SHRIRAMFIN', 'ADANIPORTS', 'AUBANK', 'CANBK', 'KPITTECH',
#        'HDFCBANK', 'TECHM', 'GUJGASLTD', 'PIIND', 'SBICARD', 'MPHASIS',
#        'JSWSTEEL', 'ZYDUSLIFE', 'DELHIVERY', 'DMART', 'ITC', 'SIEMENS',
#        'POONAWALLA', 'AMBUJACEM', 'RECLTD', 'BSE', 'VOLTAS', 'LTTS',
#        'NIFTY NEXT 50', 'GRASIM', 'HDFCAMC', 'CAMS', 'HFCL', 'PAYTM',
#        'AARTIIND', 'SJVN', 'PVRINOX', 'NAVINFLUOR', 'UPL', 'TIINDIA',
#        'TVSMOTOR', 'ADANIENT', 'ACC', 'HDFCLIFE', 'MRF', 'LODHA',
#        'MARUTI', 'LTF', 'KEI', 'UNIONBANK', 'OBEROIRLTY', 'NYKAA',
#        'HINDUNILVR', 'INDIGO', 'TATAPOWER', 'PNB', 'EXIDEIND', 'NBCC',
#        'ICICIBANK', 'BPCL', 'CANFINHOME', 'BANKBARODA', 'CONCOR', 'JSL',
#        'SOLARINDS', 'POWERGRID', 'PFC', 'RELIANCE', 'GMRAIRPORT', 'OIL',
#        'SUPREMEIND', 'INFY', 'GRANULES', 'APOLLOHOSP', 'HCLTECH',
#        'KOTAKBANK', 'GAIL', 'PRESTIGE', 'BAJAJFINSV', 'ATUL', 'IGL',
#        'UBL', 'NTPC', 'ESCORTS', 'RAMCOCEM', 'SYNGENE', 'HINDCOPPER',
#        'MARICO', 'CGPOWER', 'DEEPAKNTR', 'M&MFIN', 'ABBOTINDIA',
#        'INDIANB', 'SRF', 'SUNTV', 'ONGC', 'IEX', 'TORNTPOWER', 'SBILIFE',
#        'INDIAMART', 'HINDPETRO', 'METROPOLIS', 'GNFC'], dtype=object)

# %%
df5=df5[(df5["instrument_category"]==1) | (df5["instrument_category"]==4)]

# %%
df5["instrument_category"].unique()
# Out:
# array([1, 4])

# %%
df5["underlying_name"].unique()
# Out:
# array(['ASIANPAINT', 'JIOFIN', 'SBIN', 'WIPRO', 'M&M', 'DRREDDY',
#        'CROMPTON', 'VBL', 'BAJAJ-AUTO', 'CIPLA', 'VEDL', 'PEL', 'IRB',
#        'SONACOMS', 'HEROMOTOCO', 'DIVISLAB', 'ATGL', 'INDUSINDBK',
#        'TATACHEM', 'TRENT', 'CYIENT', 'OFSS', 'MGL', 'LAURUSLABS',
#        'TATAELXSI', 'Nifty Bank', 'AUROPHARMA', 'RBLBANK', 'JSWENERGY',
#        'JINDALSTEL', 'BERGEPAINT', 'PHOENIXLTD', 'IDEA', 'TATAMOTORS',
#        'BHARATFORG', 'MAXHEALTH', 'IRCTC', 'CHAMBLFERT', 'SUNPHARMA',
#        'GODREJCP', 'ADANIENSOL', 'BALKRISIND', 'ASHOKLEY', 'IDFCFIRSTB',
#        'PERSISTENT', 'ICICIGI', 'ULTRACEMCO', 'APOLLOTYRE', 'GODREJPROP',
#        'BRITANNIA', 'BANDHANBNK', 'YESBANK', 'NATIONALUM', 'TATASTEEL',
#        'SHREECEM', 'DABUR', 'CHOLAFIN', 'ICICIPRULI', 'BANKINDIA',
#        'EICHERMOT', 'NMDC', 'ALKEM', 'AXISBANK', 'POLYCAB', 'ABFRL',
#        'DIXON', 'Nifty Fin Service', 'NCC', 'INDUSTOWER', 'ADANIGREEN',
#        'IPCALAB', 'SAIL', 'IOC', 'HINDALCO', 'NHPC', 'MANAPPURAM',
#        'POLICYBZR', 'GLENMARK', 'MCX', 'ASTRAL', 'TITAN', 'PAGEIND',
#        'BEL', 'BSOFT', 'BAJFINANCE', 'LICI', 'BHARTIARTL', 'FEDERALBNK',
#        'TORNTPHARM', 'COROMANDEL', 'COFORGE', 'ABB', 'LT', 'ANGELONE',
#        'APLAPOLLO', 'LTIM', 'NIFTY MID SELECT', 'MUTHOOTFIN', 'PETRONET',
#        'TCS', 'LUPIN', 'LICHSGFIN', 'UNITDSPR', 'HUDCO', 'CESC', 'COLPAL',
#        'INDHOTEL', 'Nifty 50', 'IRFC', 'HAVELLS', 'BIOCON', 'COALINDIA',
#        'JUBLFOOD', '091NSETEST', 'NAUKRI', 'PIDILITIND', 'DLF',
#        'KALYANKJIL', 'MOTHERSON', 'NESTLEIND', 'MFSL', 'HAL',
#        'LALPATHLAB', 'JKCEMENT', 'ABCAPITAL', 'BHEL', 'CUMMINSIND',
#        'CDSL', 'CUB', '071NSETEST', 'BATAINDIA', 'ZOMATO', 'TATACOMM',
#        'DALBHARAT', 'BOSCHLTD', 'TATACONSUM', 'SHRIRAMFIN', 'ADANIPORTS',
#        'AUBANK', 'CANBK', 'KPITTECH', 'HDFCBANK', 'TECHM', 'GUJGASLTD',
#        'PIIND', 'SBICARD', 'MPHASIS', 'JSWSTEEL', 'ZYDUSLIFE',
#        'DELHIVERY', 'DMART', 'ITC', 'SIEMENS', 'POONAWALLA', 'AMBUJACEM',
#        'RECLTD', 'BSE', 'VOLTAS', 'LTTS', 'NIFTY NEXT 50', 'GRASIM',
#        'HDFCAMC', 'CAMS', 'HFCL', 'PAYTM', 'AARTIIND', 'SJVN', 'PVRINOX',
#        'NAVINFLUOR', 'UPL', 'TIINDIA', 'TVSMOTOR', 'ADANIENT', 'ACC',
#        'HDFCLIFE', 'MRF', 'LODHA', 'MARUTI', 'LTF', '171NSETEST', 'KEI',
#        'UNIONBANK', 'OBEROIRLTY', 'NYKAA', 'HINDUNILVR', 'INDIGO',
#        'TATAPOWER', 'PNB', 'EXIDEIND', 'NBCC', 'ICICIBANK', 'BPCL',
#        'CANFINHOME', 'BANKBARODA', 'CONCOR', 'JSL', 'SOLARINDS',
#        'POWERGRID', 'PFC', 'RELIANCE', '031NSETEST', '011NSETEST',
#        'GMRAIRPORT', '111NSETEST', 'OIL', 'SUPREMEIND', 'INFY',
#        'GRANULES', 'APOLLOHOSP', 'HCLTECH', 'KOTAKBANK', 'GAIL',
#        'PRESTIGE', 'BAJAJFINSV', '131NSETEST', 'ATUL', 'IGL', 'UBL',
#        'NTPC', 'ESCORTS', 'RAMCOCEM', 'SYNGENE', '041NSETEST',
#        '051NSETEST', '061NSETEST', 'HINDCOPPER', 'MARICO', 'CGPOWER',
#        '081NSETEST', 'DEEPAKNTR', 'M&MFIN', 'ABBOTINDIA', '021NSETEST',
#        'INDIANB', '141NSETEST', '101NSETEST', 'SRF', 'SUNTV', 'ONGC',
#        'IEX', 'TORNTPOWER', 'SBILIFE', '181NSETEST', 'INDIAMART',
#        'HINDPETRO', 'METROPOLIS', '121NSETEST', '151NSETEST',
#        '161NSETEST', 'GNFC', nan], dtype=object)

# %%
df5[df5["underlying"]=="TITAN"]
# Out:
#       exchange     token  instrument_category underlying     contract_symbol  \
# 85489    NSEFO     43400                    1      TITAN       TITAN25MARFUT
# 85829    NSEFO     73632                    1      TITAN       TITAN25APRFUT
# 86025    NSEFO     41498                    1      TITAN       TITAN25FEBFUT
# 86166    NSEFO  10666888                    4      TITAN  TITAN25FEB25MARFUT
# 86491    NSEFO  11184032                    4      TITAN  TITAN25MAR25APRFUT
#
#       instrument_type       product  contract_unique_id   price1   price2  \
# 85489          FUTSTK  TITAN-FUTSTK       2508600043400  3613.45  2956.50
# 85829          FUTSTK  TITAN-FUTSTK       2511400073632  3636.35  2975.20
# 86025          FUTSTK  TITAN-FUTSTK       2505800041498  3594.25  2940.75
# 86166          FUTSTK  TITAN-FUTSTK       2100110666888    81.70   -81.70
# 86491          FUTSTK  TITAN-FUTSTK       2100111184032    82.15   -82.15
#
#        ...  trading_status   alternate_id  underlying_name  \
# 85489  ...               1  1100100003506            TITAN
# 85829  ...               1  1100100003506            TITAN
# 86025  ...               1  1100100003506            TITAN
# 86166  ...               1             -1              NaN
# 86491  ...               1             -1              NaN
#
#                     expiry                strike option_type  \
# 85489  2025-03-27T14:30:00       TITAN 27MAR2025           1
# 85829  2025-04-24T14:30:00       TITAN 24APR2025           1
# 86025  2025-02-27T14:30:00       TITAN 27FEB2025           1
# 86166  2025-02-27T14:30:00  TITAN 27FEB27MAR SPD           1
# 86491  2025-03-27T14:30:00  TITAN 27MAR24APR SPD           1
#
#       option_description               flag1  flag2 contract_code
# 85489                  1       TITAN25MARFUT    NaN           NaN
# 85829                  1       TITAN25APRFUT    NaN           NaN
# 86025                  1       TITAN25FEBFUT    NaN           NaN
# 86166                  1  TITAN25FEB25MARFUT    NaN           NaN
# 86491                  1  TITAN25MAR25APRFUT    NaN           NaN
#
# [5 rows x 23 columns]

# %%
Nifty 50

# %%
df5
# Out:
#       exchange  token  instrument_category  underlying     contract_symbol  \
# 85397    NSEFO  69079                    1  ASIANPAINT  ASIANPAINT25APRFUT
# 85398    NSEFO  73466                    1      JIOFIN      JIOFIN25APRFUT
# 85399    NSEFO  43355                    1        SBIN        SBIN25MARFUT
# 85400    NSEFO  43438                    1       WIPRO       WIPRO25MARFUT
# 85401    NSEFO  73487                    1         M&M         M&M25APRFUT
# ...        ...    ...                  ...         ...                 ...
# 86072    NSEFO  42278                    1    KPITTECH    KPITTECH25MARFUT
# 86073    NSEFO  40480                    1       PAYTM       PAYTM25FEBFUT
# 86074    NSEFO  69084                    1    AXISBANK    AXISBANK25APRFUT
# 86075    NSEFO  43104                    1  LAURUSLABS  LAURUSLABS25MARFUT
# 86076    NSEFO  41305                    1    SHREECEM    SHREECEM25FEBFUT
#
#       instrument_type            product  contract_unique_id    price1  \
# 85397          FUTSTK  ASIANPAINT-FUTSTK       2511400069079   2485.15
# 85398          FUTSTK      JIOFIN-FUTSTK       2511400073466    254.49
# 85399          FUTSTK        SBIN-FUTSTK       2508600043355    812.20
# 85400          FUTSTK       WIPRO-FUTSTK       2508600043438    343.70
# 85401          FUTSTK         M&M-FUTSTK       2511400073487   3332.25
# ...               ...                ...                 ...       ...
# 86072          FUTSTK    KPITTECH-FUTSTK       2508600042278   1492.40
# 86073          FUTSTK       PAYTM-FUTSTK       2505800040480    823.55
# 86074          FUTSTK    AXISBANK-FUTSTK       2511400069084   1123.60
# 86075          FUTSTK  LAURUSLABS-FUTSTK       2508600043104    666.05
# 86076          FUTSTK    SHREECEM-FUTSTK       2505800041305  31062.70
#
#          price2  ...  trading_status   alternate_id  underlying_name  \
# 85397   2033.30  ...               1  1100100000236       ASIANPAINT
# 85398    208.22  ...               1  1100100018143           JIOFIN
# 85399    664.55  ...               1  1100100003045             SBIN
# 85400    281.25  ...               1  1100100003787            WIPRO
# 85401   2726.40  ...               1  1100100002031              M&M
# ...         ...  ...             ...            ...              ...
# 86072   1221.05  ...               1  1100100009683         KPITTECH
# 86073    673.80  ...               1  1100100006705            PAYTM
# 86074    919.35  ...               1  1100100005900         AXISBANK
# 86075    544.95  ...               1  1100100019234       LAURUSLABS
# 86076  25414.95  ...               1  1100100003103         SHREECEM
#
#                     expiry                strike option_type  \
# 85397  2025-04-24T14:30:00  ASIANPAINT 24APR2025           1
# 85398  2025-04-24T14:30:00      JIOFIN 24APR2025           1
# 85399  2025-03-27T14:30:00        SBIN 27MAR2025           1
# 85400  2025-03-27T14:30:00       WIPRO 27MAR2025           1
# 85401  2025-04-24T14:30:00         M&M 24APR2025           1
# ...                    ...                   ...         ...
# 86072  2025-03-27T14:30:00    KPITTECH 27MAR2025           1
# 86073  2025-02-27T14:30:00       PAYTM 27FEB2025           1
# 86074  2025-04-24T14:30:00    AXISBANK 24APR2025           1
# 86075  2025-03-27T14:30:00  LAURUSLABS 27MAR2025           1
# 86076  2025-02-27T14:30:00    SHREECEM 27FEB2025           1
#
#       option_description               flag1  flag2 contract_code
# 85397                  1  ASIANPAINT25APRFUT    NaN           NaN
# 85398                  1      JIOFIN25APRFUT    NaN           NaN
# 85399                  1        SBIN25MARFUT    NaN           NaN
# 85400                  1       WIPRO25MARFUT    NaN           NaN
# 85401                  1         M&M25APRFUT    NaN           NaN
# ...                  ...                 ...    ...           ...
# 86072                  1    KPITTECH25MARFUT    NaN           NaN
# 86073                  1       PAYTM25FEBFUT    NaN           NaN
# 86074                  1    AXISBANK25APRFUT    NaN           NaN
# 86075                  1  LAURUSLABS25MARFUT    NaN           NaN
# 86076                  1    SHREECEM25FEBFUT    NaN           NaN
#
# [662 rows x 23 columns]

# %%
df5[""].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\Desktop\YASH\Github\Spread-Engine\SpreadEngine\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OptionType'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df5["OptionType"].unique()
#
# File c:\Users\Admin\Desktop\YASH\Github\Spread-Engine\SpreadEngine\venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Admin\Desktop\YASH\Github\Spread-Engine\SpreadEngine\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'OptionType'

# %%
futures=df5[df5["instrument_type"]=="FUTSTK"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\Desktop\YASH\Github\Spread-Engine\SpreadEngine\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'instrument_type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 futures=df5[df5["instrument_type"]=="FUTSTK"]
#
# File c:\Users\Admin\Desktop\YASH\Github\Spread-Engine\SpreadEngine\venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Admin\Desktop\YASH\Github\Spread-Engine\SpreadEngine\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'instrument_type'

# %%
df5.rename(columns={"token":"ExchangeInstrumentID","contract_symbol":"Description"},inplace=True)

# %%
df5.rename(columns={"strike":"Strike"},inplace=True)

# %%
sortdf=df5.sort_values(by=["expiry"])

# %%
import re
import json

def extract_futures(symbol, df):
    """
    Extracts future contract details from the given symbol.

    Args:
    symbol (str): The future contract description.
    df (DataFrame): The DataFrame containing futures contract data.

    Returns:
    tuple: (ExchangeInstrumentID of first expiry, ExchangeInstrumentID of second expiry)
    """
    # Regular expression to match stock symbol and expiry months
    pattern = re.match(r"([A-Z\&\-]+)(\d{2}[A-Z]+)(\d{2}[A-Z]+)FUT", symbol)
    
    if pattern:
        stock_symbol = pattern.group(1)  # Extract stock symbol (e.g., TITAN)
        expiry1 = pattern.group(2)       # First expiry (e.g., 25MAR)
        expiry2 = pattern.group(3)       # Second expiry (e.g., 25APR)

        # Fetch F1 ExchangeInstrumentID
        fut1_df = df[df['Description'] == f"{stock_symbol}{expiry1}FUT"]
        fut1_exchange_id = int(fut1_df['ExchangeInstrumentID'].values[0]) if not fut1_df.empty else None

        # Fetch F2 ExchangeInstrumentID
        fut2_df = df[df['Description'] == f"{stock_symbol}{expiry2}FUT"]
        fut2_exchange_id = int(fut2_df['ExchangeInstrumentID'].values[0]) if not fut2_df.empty else None

        return fut1_exchange_id, fut2_exchange_id
    else:
        return None, None

# Dictionary to store parent-child mapping
futures_mapping = {}

# List to store ExchangeInstrumentIDs
exchange_instrument_list = []

# Iterate over descriptions ending with "SPD"
for _, row in df5[df5["Strike"].str.endswith("SPD")].iterrows():
    parent_exchange_id = int(row['ExchangeInstrumentID'])  # Convert to int
    result = extract_futures(row['Description'], df5)

    if result:
        f1_exchange_id = result[0]
        f2_exchange_id = result[1]

        # Store only if both F1 and F2 are found
        if f1_exchange_id and f2_exchange_id:
            futures_mapping[parent_exchange_id] = [f1_exchange_id, f2_exchange_id]

            # Add all IDs to the list
            exchange_instrument_list.append({"exchangeSegment": 2, "exchangeInstrumentID": f1_exchange_id})
            exchange_instrument_list.append({"exchangeSegment": 2, "exchangeInstrumentID": f2_exchange_id})

    # Add parent exchangeInstrumentID to the list as well
    exchange_instrument_list.append({"exchangeSegment": 2, "exchangeInstrumentID": parent_exchange_id})

# Remove duplicates from the list
exchange_instrument_list = list({v["exchangeInstrumentID"]: v for v in exchange_instrument_list}.values())

# Save Futures Mapping to JSON
futures_mapping_file = r"data\futures_mapping2.json"
with open(futures_mapping_file, "w") as json_file:
    json.dump(futures_mapping, json_file, indent=4)

# Save ExchangeInstrumentID List to JSON
exchange_instrument_file = r"data\exchange_instruments2.json"
with open(exchange_instrument_file, "w") as json_file:
    json.dump(exchange_instrument_list, json_file, indent=4)

print(f"✅ Futures mapping saved at: {futures_mapping_file}")
print(f"✅ Exchange Instrument List saved at: {exchange_instrument_file}")



#create a dic of ExchangeInstrumentID and  Description

df1=df5[["ExchangeInstrumentID","Description"]]
df1=df1.drop_duplicates()
df1=df1.set_index("ExchangeInstrumentID")
df1=df1.to_dict()
#save to json
import json
with open('ExchangeInstrumentID.json', 'w') as fp:
    json.dump(df1, fp)
# Out:
# ✅ Futures mapping saved at: data\futures_mapping2.json
# ✅ Exchange Instrument List saved at: data\exchange_instruments2.json

# %%
df1=df5[["ExchangeInstrumentID","Description"]]
df1=df1.drop_duplicates()
df1=df1.set_index("ExchangeInstrumentID")
df1=df1.to_dict()
#save to json
import json
with open('ExchangeInstrumentID2.json', 'w') as fp:
    json.dump(df1, fp)

# %%
df5["lot_size"]
# Out:
# 85397      200
# 85398     1650
# 85399      750
# 85400     3000
# 85401      175
#          ...
# 86507    10250
# 86508     5000
# 86509     3000
# 86510     1650
# 86511     1700
# Name: lot_size, Length: 1115, dtype: int64

# %%
df6=df5.copy

# %%
df1 = df5[["ExchangeInstrumentID", "lot_size"]]
df1 = df1.drop_duplicates()
df1 = df1.set_index("ExchangeInstrumentID")
df1 = df1.to_dict()
# save to json
import json
with open('lotsize.json', 'w') as fp:
    json.dump(df1, fp)

# %%
futures["lot_size"]
# Out:
# 85397      200
# 85398     1650
# 85399      750
# 85400     3000
# 85401      175
#          ...
# 86507    10250
# 86508     5000
# 86509     3000
# 86510     1650
# 86511     1700
# Name: lot_size, Length: 1085, dtype: int64
